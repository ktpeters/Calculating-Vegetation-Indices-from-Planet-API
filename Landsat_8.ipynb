# %% [markdown]
# <a href="https://colab.research.google.com/github/ktpeters/Calculating-Vegetation-Indices-from-Planet-API/blob/main/Landsat_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install earthengine-api

# %%
import ee
import os
import time

# %%
# # Get the path to the credentials file
credentials_path = os.path.expanduser("~/.config/earthengine/credentials")

 # Remove the credentials file if it exists
if os.path.exists(credentials_path):
     os.remove(credentials_path)
     print("Earth Engine credentials removed. You are now unauthenticated.")
else:
     print("No Earth Engine credentials found.")
# Out:
# No Earth Engine credentials found.

# %%
# Trigger the authentication flow. You only need to do this once.
ee.Authenticate()
# Initialize the library.
ee.Initialize(project='ee-covercropproject')

# %%
# Define the FeatureCollection
state_abb = 'MO'
polygons = ee.FeatureCollection(f"projects/ee-covercropproject/assets/CLU_{state_abb}")

# Sort the FeatureCollection by a specific property before converting to a list
sortedCollection = polygons.sort('ID')
featureList = sortedCollection.toList(sortedCollection.size())

# %%
# Define a function to mask clouds, cloud shadows, and snow/ice using the QA_PIXEL band
def mask_clouds(image):
    # Select the QA_PIXEL band
    qa = image.select('QA_PIXEL')

    # Define bitmasks for clouds, cloud shadows, and snow/ice
    cloud_bitmask = 1 << 3
    shadow_bitmask = 1 << 4
    snow_bitmask = 1 << 5

    # Create a mask for clear conditions (no clouds, no shadows, no snow/ice)
    cloud_mask = qa.bitwiseAnd(cloud_bitmask).eq(0)  # No cloud
    shadow_mask = qa.bitwiseAnd(shadow_bitmask).eq(0)  # No cloud shadow
    snow_mask = qa.bitwiseAnd(snow_bitmask).eq(0)  # No snow/ice

    # Combine the masks
    final_mask = cloud_mask.And(shadow_mask).And(snow_mask)

    # Apply the mask to the image
    return image.updateMask(final_mask)

# Function to calculate various indices and add date
def addNDVInDate(image):
    ndvi = image.normalizedDifference(['SR_B5', 'SR_B4']).rename('NDVI')
    tvi = image.expression(
        '(pow((((B8-B4)/(B8+B4)) +(1/2)),(1/2)))*100', {
            'B8': image.select('SR_B5'),
            'B4': image.select('SR_B4')
        }).rename('TVI')
    evi = image.expression(
        '2.5* ( (B8-B4)/ (B8+ 6*B4 - 7.5*B2 +1))', {
            'B4': image.select('SR_B4'),
            'B8': image.select('SR_B5'),
            'B2': image.select('SR_B2')
        }).rename('EVI')
    satvi = image.expression(
        '((B11-B4)/(B11+B4+1)) * (1+1) - (B12/2)', {
            'B11': image.select('SR_B6'),
            'B4': image.select('SR_B4'),
            'B12': image.select('SR_B7')
        }).rename('SATVI')
    savi = image.expression(
        '((B8-B4) + (1+0.5))/ (B8-B4+0.5)', {
            'B4': image.select('SR_B4'),
            'B8': image.select('SR_B5')
        }).rename('SAVI')
    msi = image.expression(
        '(B11/B8)', {
            'B11': image.select('SR_B6'),
            'B8': image.select('SR_B5')
        }).rename('MSI')
    gndvi = image.normalizedDifference(['SR_B5', 'SR_B3']).rename('GNDVI')
    grvi = image.normalizedDifference(['SR_B3', 'SR_B4']).rename('GRVI')
    lswi = image.normalizedDifference(['SR_B5', 'SR_B6']).rename('LSWI')
    msavi2 = image.expression(
        '(2 * B5 + 1 - sqrt(pow((2 * B5 + 1), 2) - 8 * (B5 - B4)) ) / 2', {
            'B5': image.select('SR_B5'),
            'B4': image.select('SR_B4')
        }).rename('MSAVI2')
    wdvi = image.expression(
        'B8- 0.5*B4', {
            'B4': image.select('SR_B4'),
            'B8': image.select('SR_B5')
        }).rename('WDVI')
    bi = image.expression(
        'sqrt((B4*B4) +(B3*B3))/2', {
            'B4': image.select('SR_B4'),
            'B3': image.select('SR_B3')
        }).rename('BI')
    bi2 = image.expression(
        'sqrt((B4*B4) +(B3*B3)+(B8*B8))/3', {
            'B4': image.select('SR_B4'),
            'B3': image.select('SR_B3'),
            'B8': image.select('SR_B5')
        }).rename('BI2')
    ri = image.expression(
        '(B4*B4)/(B3*B3*B3)', {
            'B4': image.select('SR_B4'),
            'B3': image.select('SR_B3')
        }).rename('RI')
    ci = image.normalizedDifference(['SR_B4', 'SR_B3']).rename('CI')
    v = image.expression(
        '(B8/B4)', {
            'B8': image.select('SR_B5'),
            'B4': image.select('SR_B4')
        }).rename('V')
    ndwi = image.normalizedDifference(['SR_B5', 'SR_B6']).rename('NDWI')
    nbr = image.normalizedDifference(['SR_B5', 'SR_B7']).rename('NBR')

    newBands = ee.Image([ndvi, tvi, evi, satvi, savi, msi, gndvi, grvi, lswi,
                         msavi2, wdvi, bi, bi2, ri, ci, v, ndwi, nbr])
    return image.addBands(newBands)

# Function to reduce the regions and calculate statistics
def reduceRegionsFunction(image):
    stats = image.reduceRegions(
        collection=subsetFC,
        reducer=ee.Reducer.mean(),
        scale=30
    )
    stats_filtered = stats.filter(ee.Filter.notNull(['NDVI']))
    return stats_filtered.map(lambda feature: feature.set('date', image.get('system:time_start')).setGeometry(None))

# %%
# Iterate through the FeatureCollection in chunks
#time.sleep(15000)
stepsize=1000
for i in range(0, sortedCollection.size().getInfo(), stepsize):
    subset = featureList.slice(i, i+stepsize)
    subsetFC = ee.FeatureCollection(subset)
    convexHull = subsetFC.geometry().convexHull().buffer(50)

    # Download NDVI data for each year
    for yr in range(2015, 2025):
        startDate = f'{yr-1}-05-15'
        endDate = f'{yr}-5-15'
        fileName = f'NDVI_{yr-1}_{i}'

        landsat = (ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')
                 .filterBounds(convexHull)
                 .filterDate(startDate, endDate)
                 .map(mask_clouds)
                 .map(addNDVInDate))

        reduced = landsat.map(reduceRegionsFunction).flatten()

        # Remove geometry before exporting
        reduced_no_geom = reduced.map(lambda feature: feature.setGeometry(None))

        # Export the data to Google Drive
        task = ee.batch.Export.table.toDrive(
            collection=reduced_no_geom,
            description=fileName,
            folder=f'Landsat8_CLU_{state_abb}_sorted',
            fileFormat='CSV'
        )
        task.start()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     405   try:
# --> 406     return call.execute(num_retries=num_retries)
#     407   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.10/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/ee-covercropproject/table:export?alt=json returned "Too many tasks already in the queue (3000, limit 3000).". Details: "Too many tasks already in the queue (3000, limit 3000).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# <ipython-input-6-fb6d81c0fef7> in <cell line: 4>()
#      31             fileFormat='CSV'
#      32         )
# ---> 33         task.start()
#
# /usr/local/lib/python3.10/dist-packages/ee/batch.py in start(self)
#     147       result = data.exportMap(self._request_id, self.config)
#     148     elif self.task_type == Task.Type.EXPORT_TABLE:
# --> 149       result = data.exportTable(self._request_id, self.config)
#     150     elif self.task_type == Task.Type.EXPORT_VIDEO:
#     151       result = data.exportVideo(self._request_id, self.config)
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in exportTable(request_id, params)
#    1788   """
#    1789   params = params.copy()
# -> 1790   return _prepare_and_run_export(
#    1791       request_id, params, _get_cloud_projects().table().export
#    1792   )
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _prepare_and_run_export(request_id, params, export_endpoint)
#    1905         params['expression'], for_cloud_api=True)
#    1906   num_retries = _max_retries if request_id else 0
# -> 1907   return _execute_cloud_call(
#    1908       export_endpoint(project=_get_projects_path(), body=params),
#    1909       num_retries=num_retries)
#
# /usr/local/lib/python3.10/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     406     return call.execute(num_retries=num_retries)
#     407   except googleapiclient.errors.HttpError as e:
# --> 408     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     409
#     410
#
# EEException: Too many tasks already in the queue (3000, limit 3000).

# %%
### To cancel tasks
# # Get a list of all tasks
# tasks = ee.batch.Task.list()
#
# # Iterate through the tasks and cancel them
# for task in tasks:
#     task_status = task.status()
#     print(task)
#     if (task_status['state'] in ['RUNNING', 'READY']) and (task_status['description'].startswith('NDVI_2017')):
#         task.cancel()
#         print(f"Cancelled task {task.id}: {task_status['description']}")
# Out:
# <Task OOSZIBEX2Y4IP6FLOKI5ZK5X EXPORT_FEATURES: NDVI_2017_410000 (CANCELLED)>
# <Task BFNGQA6JLXNIYQQFWBH5ZFNE EXPORT_FEATURES: NDVI_2016_410000 (CANCELLED)>
# <Task OJC35SVA4XQDPVWJKRUT75OA EXPORT_FEATURES: NDVI_2015_410000 (CANCELLED)>
# <Task ZRDVID3H7RK43V7ZCUQ3INK2 EXPORT_FEATURES: NDVI_2014_410000 (CANCELLED)>
# <Task OAMFUMYKCO6246F66ULBMMMP EXPORT_FEATURES: NDVI_2023_409000 (READY)>
# Cancelled task OAMFUMYKCO6246F66ULBMMMP: NDVI_2023_409000
# <Task PVH4KFYK6ILHLFZP3VAUKN5B EXPORT_FEATURES: NDVI_2022_409000 (READY)>
# Cancelled task PVH4KFYK6ILHLFZP3VAUKN5B: NDVI_2022_409000
# <Task FTJJKQQTQMOXOYHXHLLZ6YHG EXPORT_FEATURES: NDVI_2021_409000 (READY)>
# Cancelled task FTJJKQQTQMOXOYHXHLLZ6YHG: NDVI_2021_409000
# <Task SS53INICNLVACJGG2VH5JHWG EXPORT_FEATURES: NDVI_2020_409000 (READY)>
# Cancelled task SS53INICNLVACJGG2VH5JHWG: NDVI_2020_409000
# <Task M6CHSILC3PMIINOZLILZWV2M EXPORT_FEATURES: NDVI_2019_409000 (READY)>
# Cancelled task M6CHSILC3PMIINOZLILZWV2M: NDVI_2019_409000
# <Task CV2ODYAYQZANDFW6P7ZLFFUT EXPORT_FEATURES: NDVI_2018_409000 (READY)>
# Cancelled task CV2ODYAYQZANDFW6P7ZLFFUT: NDVI_2018_409000
# <Task Y3BRUMORG423YMUB5YBXMWWU EXPORT_FEATURES: NDVI_2017_409000 (READY)>
# Cancelled task Y3BRUMORG423YMUB5YBXMWWU: NDVI_2017_409000
# <Task MM45OUOZZQZUFBZWZOS34DDA EXPORT_FEATURES: NDVI_2016_409000 (READY)>
# Cancelled task MM45OUOZZQZUFBZWZOS34DDA: NDVI_2016_409000
# <Task ZLIGYOFHWLZIDBLQOIW43XRC EXPORT_FEATURES: NDVI_2015_409000 (READY)>
# Cancelled task ZLIGYOFHWLZIDBLQOIW43XRC: NDVI_2015_409000
# <Task NKQ5PISR66QSEHTEIPQ7QE5D EXPORT_FEATURES: NDVI_2014_409000 (READY)>
# Cancelled task NKQ5PISR66QSEHTEIPQ7QE5D: NDVI_2014_409000
# <Task VHDRJHLPOND4MCMNX5C3JFNV EXPORT_FEATURES: NDVI_2023_408000 (READY)>
# Cancelled task VHDRJHLPOND4MCMNX5C3JFNV: NDVI_2023_408000
# <Task T6MQAHF4KPRIXVEZ6KEYB6YU EXPORT_FEATURES: NDVI_2022_408000 (READY)>
# Cancelled task T6MQAHF4KPRIXVEZ6KEYB6YU: NDVI_2022_408000
# <Task YFCTWRMQPPJM7QIE6NDXNA47 EXPORT_FEATURES: NDVI_2021_408000 (READY)>
# Cancelled task YFCTWRMQPPJM7QIE6NDXNA47: NDVI_2021_408000
# <Task HWBB3E5H4A4YLUW3YXMPXPMU EXPORT_FEATURES: NDVI_2020_408000 (READY)>
# Cancelled task HWBB3E5H4A4YLUW3YXMPXPMU: NDVI_2020_408000
# <Task IUQ5NXW4ZHWY7NC56AFYZ4KJ EXPORT_FEATURES: NDVI_2019_408000 (READY)>
# Cancelled task IUQ5NXW4ZHWY7NC56AFYZ4KJ: NDVI_2019_408000
# <Task XBQNPHTSNNHA5WM7ROG2I47C EXPORT_FEATURES: NDVI_2018_408000 (READY)>
# Cancelled task XBQNPHTSNNHA5WM7ROG2I47C: NDVI_2018_408000
# <Task 35MZPYIATYZWF4E4BEWYW6EQ EXPORT_FEATURES: NDVI_2017_408000 (READY)>
# Cancelled task 35MZPYIATYZWF4E4BEWYW6EQ: NDVI_2017_408000
# <Task 3UMTTY6DMMYZNLPKRLXIP2FW EXPORT_FEATURES: NDVI_2016_408000 (READY)>
# Cancelled task 3UMTTY6DMMYZNLPKRLXIP2FW: NDVI_2016_408000
# <Task GDM4YNXZCQJJFFID6NVU24OH EXPORT_FEATURES: NDVI_2015_408000 (READY)>
# Cancelled task GDM4YNXZCQJJFFID6NVU24OH: NDVI_2015_408000
# <Task 3KNKCHHNSJTUUGZCWNC3UJXX EXPORT_FEATURES: NDVI_2014_408000 (READY)>
# Cancelled task 3KNKCHHNSJTUUGZCWNC3UJXX: NDVI_2014_408000
# <Task JZJNEACFWQJHLR7EI5SESKUU EXPORT_FEATURES: NDVI_2023_407000 (READY)>
# Cancelled task JZJNEACFWQJHLR7EI5SESKUU: NDVI_2023_407000
# <Task WLCGDLB5C6R67WUDQGYBH5XC EXPORT_FEATURES: NDVI_2022_407000 (READY)>
# Cancelled task WLCGDLB5C6R67WUDQGYBH5XC: NDVI_2022_407000
# <Task URGCFR7K6DLK7RAJNDLAG3FL EXPORT_FEATURES: NDVI_2021_407000 (READY)>
# Cancelled task URGCFR7K6DLK7RAJNDLAG3FL: NDVI_2021_407000
# <Task GR3PHQCBG7PE4Y6344MOKJQI EXPORT_FEATURES: NDVI_2020_407000 (READY)>
# Cancelled task GR3PHQCBG7PE4Y6344MOKJQI: NDVI_2020_407000
# <Task LZBU4ZJFJLF2JMLAOUF5B2TC EXPORT_FEATURES: NDVI_2019_407000 (READY)>
# Cancelled task LZBU4ZJFJLF2JMLAOUF5B2TC: NDVI_2019_407000
# <Task IQV4A3V3YJYRYAO45POGFOOI EXPORT_FEATURES: NDVI_2018_407000 (READY)>
# Cancelled task IQV4A3V3YJYRYAO45POGFOOI: NDVI_2018_407000
# <Task V2QCIJATW7X2HX2GYQQ42H4O EXPORT_FEATURES: NDVI_2017_407000 (READY)>
# Cancelled task V2QCIJATW7X2HX2GYQQ42H4O: NDVI_2017_407000
# <Task NVVXGA4QI42CY2AYYV7B5FXR EXPORT_FEATURES: NDVI_2016_407000 (READY)>
# Cancelled task NVVXGA4QI42CY2AYYV7B5FXR: NDVI_2016_407000
# <Task OJMFSZG56R2T4DMZ5DI7H6DM EXPORT_FEATURES: NDVI_2015_407000 (READY)>
# Cancelled task OJMFSZG56R2T4DMZ5DI7H6DM: NDVI_2015_407000
# <Task KRPX4ZW47RS7YHBHWYXJKTR2 EXPORT_FEATURES: NDVI_2014_407000 (READY)>
# Cancelled task KRPX4ZW47RS7YHBHWYXJKTR2: NDVI_2014_407000
# <Task 67GYN7TX6ODDU6BXNIDMLY4M EXPORT_FEATURES: NDVI_2023_406000 (READY)>
# Cancelled task 67GYN7TX6ODDU6BXNIDMLY4M: NDVI_2023_406000
# <Task AURPBR64UDO7HWNK5ADDXG3U EXPORT_FEATURES: NDVI_2022_406000 (READY)>
# Cancelled task AURPBR64UDO7HWNK5ADDXG3U: NDVI_2022_406000
# <Task A5LULG3RII7OPBEHZ3T7NZKQ EXPORT_FEATURES: NDVI_2021_406000 (READY)>
# Cancelled task A5LULG3RII7OPBEHZ3T7NZKQ: NDVI_2021_406000
# <Task KPRKRUIYWDI3NDQ5HX2NOWUL EXPORT_FEATURES: NDVI_2020_406000 (READY)>
# Cancelled task KPRKRUIYWDI3NDQ5HX2NOWUL: NDVI_2020_406000
# <Task AANZKEEAZ4FGKOBO544QFK5A EXPORT_FEATURES: NDVI_2019_406000 (READY)>
# Cancelled task AANZKEEAZ4FGKOBO544QFK5A: NDVI_2019_406000
# <Task HHBUBNSJW3EWUSWR4VZ43QVX EXPORT_FEATURES: NDVI_2018_406000 (READY)>
# Cancelled task HHBUBNSJW3EWUSWR4VZ43QVX: NDVI_2018_406000
# <Task 6PQA3S2X5FJGIFJVPLSQELJB EXPORT_FEATURES: NDVI_2017_406000 (READY)>
# Cancelled task 6PQA3S2X5FJGIFJVPLSQELJB: NDVI_2017_406000
# <Task EG72KOFHCCFODCRMD3R53PHT EXPORT_FEATURES: NDVI_2016_406000 (READY)>
# Cancelled task EG72KOFHCCFODCRMD3R53PHT: NDVI_2016_406000
# <Task FZN5SEDUKWKSOUY2X2EKH5LM EXPORT_FEATURES: NDVI_2015_406000 (READY)>
# Cancelled task FZN5SEDUKWKSOUY2X2EKH5LM: NDVI_2015_406000
# <Task JYDE25567W3HIPWNU23MM6HG EXPORT_FEATURES: NDVI_2014_406000 (READY)>
# Cancelled task JYDE25567W3HIPWNU23MM6HG: NDVI_2014_406000
# <Task VZF4UQTU3WPKTI2XILS753QI EXPORT_FEATURES: NDVI_2023_405000 (READY)>
# Cancelled task VZF4UQTU3WPKTI2XILS753QI: NDVI_2023_405000
# <Task R3EPVJGNXJ2E2ZFR4YQYPC6E EXPORT_FEATURES: NDVI_2022_405000 (READY)>
# Cancelled task R3EPVJGNXJ2E2ZFR4YQYPC6E: NDVI_2022_405000
# <Task VDOIEKOG53GLTNLH2B3BI62L EXPORT_FEATURES: NDVI_2021_405000 (READY)>
# Cancelled task VDOIEKOG53GLTNLH2B3BI62L: NDVI_2021_405000
# <Task QZZUODIPX3T3E53ZIERPUJLA EXPORT_FEATURES: NDVI_2020_405000 (READY)>
# Cancelled task QZZUODIPX3T3E53ZIERPUJLA: NDVI_2020_405000
# <Task 3M53ITR5MLG7ROU2P7MG7LCM EXPORT_FEATURES: NDVI_2019_405000 (READY)>
# Cancelled task 3M53ITR5MLG7ROU2P7MG7LCM: NDVI_2019_405000
# <Task PJMI4SST3KA6ZM66BJI23EPT EXPORT_FEATURES: NDVI_2018_405000 (READY)>
# Cancelled task PJMI4SST3KA6ZM66BJI23EPT: NDVI_2018_405000
# <Task B7REA5TZTCD2XBEIXPA6VR2K EXPORT_FEATURES: NDVI_2017_405000 (READY)>
# Cancelled task B7REA5TZTCD2XBEIXPA6VR2K: NDVI_2017_405000
# <Task Y7PDOZLNPUPCSSN2IBBBUVFU EXPORT_FEATURES: NDVI_2016_405000 (READY)>
# Cancelled task Y7PDOZLNPUPCSSN2IBBBUVFU: NDVI_2016_405000
# <Task V4HBBUNC2MHNVI4GFV27EHTK EXPORT_FEATURES: NDVI_2015_405000 (READY)>
# Cancelled task V4HBBUNC2MHNVI4GFV27EHTK: NDVI_2015_405000
# <Task I25WW4MST7NKMBXKQIGYAKZR EXPORT_FEATURES: NDVI_2014_405000 (READY)>
# Cancelled task I25WW4MST7NKMBXKQIGYAKZR: NDVI_2014_405000
# <Task MBEZMMR3SCAL6GBJEUSBGT4G EXPORT_FEATURES: NDVI_2023_404000 (READY)>
# Cancelled task MBEZMMR3SCAL6GBJEUSBGT4G: NDVI_2023_404000
# <Task OQ4HCNHJ475Z4Q4QWOOROZBX EXPORT_FEATURES: NDVI_2022_404000 (READY)>
# Cancelled task OQ4HCNHJ475Z4Q4QWOOROZBX: NDVI_2022_404000
# <Task JQZ4JXQKSMQQ66HRWS3UAAMU EXPORT_FEATURES: NDVI_2021_404000 (READY)>
# Cancelled task JQZ4JXQKSMQQ66HRWS3UAAMU: NDVI_2021_404000
# <Task E6JI3TUVVQ2GHWI4MTZZGD6Z EXPORT_FEATURES: NDVI_2020_404000 (READY)>
# Cancelled task E6JI3TUVVQ2GHWI4MTZZGD6Z: NDVI_2020_404000
# <Task MBHFUYYZHKR3FZ44AKYV34DI EXPORT_FEATURES: NDVI_2019_404000 (READY)>
# Cancelled task MBHFUYYZHKR3FZ44AKYV34DI: NDVI_2019_404000
# <Task 3HYNFBSCKSSVVTCMBNH2F6FO EXPORT_FEATURES: NDVI_2018_404000 (READY)>
# Cancelled task 3HYNFBSCKSSVVTCMBNH2F6FO: NDVI_2018_404000
# <Task WJP4Z6WZHICEUMF2OXLVTJTF EXPORT_FEATURES: NDVI_2017_404000 (READY)>
# Cancelled task WJP4Z6WZHICEUMF2OXLVTJTF: NDVI_2017_404000
# <Task IHC7QEGE3ZPKFXYI3ZFBILKL EXPORT_FEATURES: NDVI_2016_404000 (READY)>
# Cancelled task IHC7QEGE3ZPKFXYI3ZFBILKL: NDVI_2016_404000
# <Task O2CKL7K3WMOXDRBNJZGYVDV6 EXPORT_FEATURES: NDVI_2015_404000 (READY)>
# Cancelled task O2CKL7K3WMOXDRBNJZGYVDV6: NDVI_2015_404000
# <Task F5OYHSEPTRT4ABV5TP5YUXIW EXPORT_FEATURES: NDVI_2014_404000 (READY)>
# Cancelled task F5OYHSEPTRT4ABV5TP5YUXIW: NDVI_2014_404000
# <Task 4DRQPKM5W6AQN4LKJLW2IEVY EXPORT_FEATURES: NDVI_2023_403000 (READY)>
# Cancelled task 4DRQPKM5W6AQN4LKJLW2IEVY: NDVI_2023_403000
# <Task JL22OLTT4AXINEYJ2VMVQ6KN EXPORT_FEATURES: NDVI_2022_403000 (READY)>
# Cancelled task JL22OLTT4AXINEYJ2VMVQ6KN: NDVI_2022_403000
# <Task MA277QLVEWZSL25CLMI5TLG5 EXPORT_FEATURES: NDVI_2021_403000 (READY)>
# Cancelled task MA277QLVEWZSL25CLMI5TLG5: NDVI_2021_403000
# <Task FWGV422DGYF3JU7GYWPMYDQU EXPORT_FEATURES: NDVI_2020_403000 (READY)>
# Cancelled task FWGV422DGYF3JU7GYWPMYDQU: NDVI_2020_403000
# <Task PCZXRPMNQWJPYBO5UKM4KRWG EXPORT_FEATURES: NDVI_2019_403000 (READY)>
# Cancelled task PCZXRPMNQWJPYBO5UKM4KRWG: NDVI_2019_403000
# <Task DVDL3NEUIEMOBOXXMJCO5HSB EXPORT_FEATURES: NDVI_2018_403000 (READY)>
# Cancelled task DVDL3NEUIEMOBOXXMJCO5HSB: NDVI_2018_403000
# <Task KNYQ7WOSGUXSNW2CWXRVTWX6 EXPORT_FEATURES: NDVI_2017_403000 (READY)>
# Cancelled task KNYQ7WOSGUXSNW2CWXRVTWX6: NDVI_2017_403000
# <Task YKJQHUDIODCQY7RGCZJHEGP3 EXPORT_FEATURES: NDVI_2016_403000 (READY)>
# Cancelled task YKJQHUDIODCQY7RGCZJHEGP3: NDVI_2016_403000
# <Task AHKVVQCV7MFFOZ74TPMLWRWU EXPORT_FEATURES: NDVI_2015_403000 (READY)>
# Cancelled task AHKVVQCV7MFFOZ74TPMLWRWU: NDVI_2015_403000
# <Task GHFMFZVMCMWNIFNUFFROVDT2 EXPORT_FEATURES: NDVI_2014_403000 (READY)>
# Cancelled task GHFMFZVMCMWNIFNUFFROVDT2: NDVI_2014_403000
# <Task HEB4GXYNXF4UQYYSQ7FY2E45 EXPORT_FEATURES: NDVI_2023_402000 (READY)>
# Cancelled task HEB4GXYNXF4UQYYSQ7FY2E45: NDVI_2023_402000
# <Task GV5AEPFF44ZNW62CO5MF44J3 EXPORT_FEATURES: NDVI_2022_402000 (READY)>
# Cancelled task GV5AEPFF44ZNW62CO5MF44J3: NDVI_2022_402000
# <Task MK4PEEHAXCRLFQ3DLU52APWN EXPORT_FEATURES: NDVI_2021_402000 (READY)>
# Cancelled task MK4PEEHAXCRLFQ3DLU52APWN: NDVI_2021_402000
# <Task XU3ZYQKYWCX3K73LEDS4RR2A EXPORT_FEATURES: NDVI_2020_402000 (READY)>
# Cancelled task XU3ZYQKYWCX3K73LEDS4RR2A: NDVI_2020_402000
# <Task OZGKQ73GDCUNRP7X2M2S45DU EXPORT_FEATURES: NDVI_2019_402000 (READY)>
# Cancelled task OZGKQ73GDCUNRP7X2M2S45DU: NDVI_2019_402000
# <Task TPTJNBSZ7VZEY3WEA2DEZISY EXPORT_FEATURES: NDVI_2018_402000 (READY)>
# Cancelled task TPTJNBSZ7VZEY3WEA2DEZISY: NDVI_2018_402000
# <Task EESZ55HYWKXENDDRYPDUHNNQ EXPORT_FEATURES: NDVI_2017_402000 (READY)>
# Cancelled task EESZ55HYWKXENDDRYPDUHNNQ: NDVI_2017_402000
# <Task G7MXOR6DVXP4UZLDWUNQ5ITM EXPORT_FEATURES: NDVI_2016_402000 (READY)>
# Cancelled task G7MXOR6DVXP4UZLDWUNQ5ITM: NDVI_2016_402000
# <Task VPHLQKHPLQWLRFUPZCXT4KON EXPORT_FEATURES: NDVI_2015_402000 (READY)>
# Cancelled task VPHLQKHPLQWLRFUPZCXT4KON: NDVI_2015_402000
# <Task LD7UE76F7622DMRMSM2HJPNY EXPORT_FEATURES: NDVI_2014_402000 (READY)>
# Cancelled task LD7UE76F7622DMRMSM2HJPNY: NDVI_2014_402000
# <Task 5I4QMKCVRXWIMZGDNZZ7MSRK EXPORT_FEATURES: NDVI_2023_401000 (READY)>
# Cancelled task 5I4QMKCVRXWIMZGDNZZ7MSRK: NDVI_2023_401000
# <Task YCJXHV2QFJNZQ36S5DLPSAV6 EXPORT_FEATURES: NDVI_2022_401000 (READY)>
# Cancelled task YCJXHV2QFJNZQ36S5DLPSAV6: NDVI_2022_401000
# <Task 5WYOSIZT5O55YLSKT2J2DYLL EXPORT_FEATURES: NDVI_2021_401000 (READY)>
# Cancelled task 5WYOSIZT5O55YLSKT2J2DYLL: NDVI_2021_401000
# <Task EHP4TLRO4IS5W5PLCWY3EB5B EXPORT_FEATURES: NDVI_2020_401000 (READY)>
# Cancelled task EHP4TLRO4IS5W5PLCWY3EB5B: NDVI_2020_401000
# <Task 6I4SZJGYBHAMZEBN6WRA5WGJ EXPORT_FEATURES: NDVI_2019_401000 (READY)>
# Cancelled task 6I4SZJGYBHAMZEBN6WRA5WGJ: NDVI_2019_401000
# <Task 2JLWJ44S6I4HRBD2DW3AWRFS EXPORT_FEATURES: NDVI_2018_401000 (READY)>
# Cancelled task 2JLWJ44S6I4HRBD2DW3AWRFS: NDVI_2018_401000
# <Task IOFSVTINUB6WU565XOHL56VJ EXPORT_FEATURES: NDVI_2017_401000 (READY)>
# Cancelled task IOFSVTINUB6WU565XOHL56VJ: NDVI_2017_401000
# <Task Q7NAAZE4VBNCBFSOB6NTVKW7 EXPORT_FEATURES: NDVI_2016_401000 (READY)>
# Cancelled task Q7NAAZE4VBNCBFSOB6NTVKW7: NDVI_2016_401000
# <Task 2KW6ZSMQ5CDJNJPIQSJQ2YHI EXPORT_FEATURES: NDVI_2015_401000 (READY)>
# Cancelled task 2KW6ZSMQ5CDJNJPIQSJQ2YHI: NDVI_2015_401000
# <Task P6EP22GGGY74R3OWJ4A2HUES EXPORT_FEATURES: NDVI_2014_401000 (READY)>
# Cancelled task P6EP22GGGY74R3OWJ4A2HUES: NDVI_2014_401000
# <Task 5ICK7ITZJZ6FVFIHIV5P4OEW EXPORT_FEATURES: NDVI_2023_400000 (READY)>
# Cancelled task 5ICK7ITZJZ6FVFIHIV5P4OEW: NDVI_2023_400000
# <Task 2DYGMMLUUCRVNO43JYS4N44Q EXPORT_FEATURES: NDVI_2022_400000 (READY)>
# Cancelled task 2DYGMMLUUCRVNO43JYS4N44Q: NDVI_2022_400000
# <Task 6N7PN4DU466H46ZCBNHTBAEB EXPORT_FEATURES: NDVI_2021_400000 (READY)>
# Cancelled task 6N7PN4DU466H46ZCBNHTBAEB: NDVI_2021_400000
# <Task Z4FXGG2GKBUCPSTREYQVGE6S EXPORT_FEATURES: NDVI_2020_400000 (READY)>
# Cancelled task Z4FXGG2GKBUCPSTREYQVGE6S: NDVI_2020_400000
# <Task 4IDY3UOEVY5DTQKUIFTO232J EXPORT_FEATURES: NDVI_2019_400000 (READY)>
# Cancelled task 4IDY3UOEVY5DTQKUIFTO232J: NDVI_2019_400000
# <Task SOK6UGQPPD4VOGZSTVJ3LUYM EXPORT_FEATURES: NDVI_2018_400000 (READY)>
# Cancelled task SOK6UGQPPD4VOGZSTVJ3LUYM: NDVI_2018_400000
# <Task LM3SHEHVEYJCVX2XZOKR24Z4 EXPORT_FEATURES: NDVI_2017_400000 (READY)>
# Cancelled task LM3SHEHVEYJCVX2XZOKR24Z4: NDVI_2017_400000
# <Task MYMXH2QCXSGTTP4XVFPKKMMM EXPORT_FEATURES: NDVI_2016_400000 (READY)>
# Cancelled task MYMXH2QCXSGTTP4XVFPKKMMM: NDVI_2016_400000
# <Task Q3BHF6U2O3XZV4FKXRZ7QZQD EXPORT_FEATURES: NDVI_2015_400000 (READY)>
# Cancelled task Q3BHF6U2O3XZV4FKXRZ7QZQD: NDVI_2015_400000
# <Task BXJZQSROFK3IZU3JJV6HDIQ7 EXPORT_FEATURES: NDVI_2014_400000 (READY)>
# Cancelled task BXJZQSROFK3IZU3JJV6HDIQ7: NDVI_2014_400000
# <Task YNC4ZJPZOL2HCLO4DRGZ5DOZ EXPORT_FEATURES: NDVI_2023_399000 (READY)>
# Cancelled task YNC4ZJPZOL2HCLO4DRGZ5DOZ: NDVI_2023_399000
# <Task SFTLAIWW2XGNIR2FG4TSKJFG EXPORT_FEATURES: NDVI_2022_399000 (READY)>
# Cancelled task SFTLAIWW2XGNIR2FG4TSKJFG: NDVI_2022_399000
# <Task YB2LUCMR4YSR2OCVE45QRVIG EXPORT_FEATURES: NDVI_2021_399000 (READY)>
# Cancelled task YB2LUCMR4YSR2OCVE45QRVIG: NDVI_2021_399000
# <Task ZHPWZT36QDDQSEVDADHQANHO EXPORT_FEATURES: NDVI_2020_399000 (READY)>
# Cancelled task ZHPWZT36QDDQSEVDADHQANHO: NDVI_2020_399000
# <Task SUQN62T5BX3QT7ARBVXQ3JOT EXPORT_FEATURES: NDVI_2019_399000 (READY)>
# Cancelled task SUQN62T5BX3QT7ARBVXQ3JOT: NDVI_2019_399000
# <Task DL4NSJYAMI3P3AR5OQNHWXXA EXPORT_FEATURES: NDVI_2018_399000 (READY)>
# Cancelled task DL4NSJYAMI3P3AR5OQNHWXXA: NDVI_2018_399000
# <Task UR3GBBLDVTGH4EGZDW6OAEA2 EXPORT_FEATURES: NDVI_2017_399000 (READY)>
# Cancelled task UR3GBBLDVTGH4EGZDW6OAEA2: NDVI_2017_399000
# <Task JDSBBHCSKKZN3PJW3NUF7ZWY EXPORT_FEATURES: NDVI_2016_399000 (READY)>
# Cancelled task JDSBBHCSKKZN3PJW3NUF7ZWY: NDVI_2016_399000
# <Task FHYYJWDG2XHWDDLBGMMC534B EXPORT_FEATURES: NDVI_2015_399000 (READY)>
# Cancelled task FHYYJWDG2XHWDDLBGMMC534B: NDVI_2015_399000
# <Task GDHV2R7CZQ256XVELLTP4G4J EXPORT_FEATURES: NDVI_2014_399000 (READY)>
# Cancelled task GDHV2R7CZQ256XVELLTP4G4J: NDVI_2014_399000
# <Task MCWWOYQDLLCE4X5XYCL3BXHT EXPORT_FEATURES: NDVI_2023_398000 (READY)>
# Cancelled task MCWWOYQDLLCE4X5XYCL3BXHT: NDVI_2023_398000
# <Task TSELMRISJ3ZM4O6VRWFECYXZ EXPORT_FEATURES: NDVI_2022_398000 (READY)>
# Cancelled task TSELMRISJ3ZM4O6VRWFECYXZ: NDVI_2022_398000
# <Task PWLG5W7AVDJLZEL6Q3Y533TT EXPORT_FEATURES: NDVI_2021_398000 (READY)>
# Cancelled task PWLG5W7AVDJLZEL6Q3Y533TT: NDVI_2021_398000
# <Task JXCGZUQ3HTBFIIPTYGXYGSME EXPORT_FEATURES: NDVI_2020_398000 (READY)>
# Cancelled task JXCGZUQ3HTBFIIPTYGXYGSME: NDVI_2020_398000
# <Task TM7IFAJJVMZ2DMNISSKY3BSO EXPORT_FEATURES: NDVI_2019_398000 (READY)>
# Cancelled task TM7IFAJJVMZ2DMNISSKY3BSO: NDVI_2019_398000
# <Task OKBBCDUY5VJ3Q6Y42C23YS34 EXPORT_FEATURES: NDVI_2018_398000 (READY)>
# Cancelled task OKBBCDUY5VJ3Q6Y42C23YS34: NDVI_2018_398000
# <Task ULJWRKGBN3A4L2BMGL7ZVOUF EXPORT_FEATURES: NDVI_2017_398000 (READY)>
# Cancelled task ULJWRKGBN3A4L2BMGL7ZVOUF: NDVI_2017_398000
# <Task YI5QZULJUX4XHATD4LGE55G2 EXPORT_FEATURES: NDVI_2016_398000 (READY)>
# Cancelled task YI5QZULJUX4XHATD4LGE55G2: NDVI_2016_398000
# <Task LJB2RI74RJMKE6EZX674XKO3 EXPORT_FEATURES: NDVI_2015_398000 (READY)>
# Cancelled task LJB2RI74RJMKE6EZX674XKO3: NDVI_2015_398000
# <Task WCCJPL5CCRAOD52M6Q446PX6 EXPORT_FEATURES: NDVI_2014_398000 (READY)>
# Cancelled task WCCJPL5CCRAOD52M6Q446PX6: NDVI_2014_398000
# <Task FNSKY5MHFN2G6YVSUGFN3DJO EXPORT_FEATURES: NDVI_2023_397000 (READY)>
# Cancelled task FNSKY5MHFN2G6YVSUGFN3DJO: NDVI_2023_397000
# <Task WYVRYXWCBXB7PPXPQNDR2N6Z EXPORT_FEATURES: NDVI_2022_397000 (READY)>
# Cancelled task WYVRYXWCBXB7PPXPQNDR2N6Z: NDVI_2022_397000
# <Task VWFOPR5HI2ZVCOICLTTYU7IX EXPORT_FEATURES: NDVI_2021_397000 (READY)>
# Cancelled task VWFOPR5HI2ZVCOICLTTYU7IX: NDVI_2021_397000
# <Task 7MLZ7VJQ757SEJC6NYLXDJWX EXPORT_FEATURES: NDVI_2020_397000 (READY)>
# Cancelled task 7MLZ7VJQ757SEJC6NYLXDJWX: NDVI_2020_397000
# <Task TXRFCUT27XENWN3E2PYAGI4K EXPORT_FEATURES: NDVI_2019_397000 (READY)>
# Cancelled task TXRFCUT27XENWN3E2PYAGI4K: NDVI_2019_397000
# <Task WUKQB4KL3AL5YVGASA5P3LRB EXPORT_FEATURES: NDVI_2018_397000 (READY)>
# Cancelled task WUKQB4KL3AL5YVGASA5P3LRB: NDVI_2018_397000
# <Task PGMAJXZI77AFQDNAEEQLDKN5 EXPORT_FEATURES: NDVI_2017_397000 (READY)>
# Cancelled task PGMAJXZI77AFQDNAEEQLDKN5: NDVI_2017_397000
# <Task T2LIQA65HUZFIIOTIWAGPTKV EXPORT_FEATURES: NDVI_2016_397000 (READY)>
# Cancelled task T2LIQA65HUZFIIOTIWAGPTKV: NDVI_2016_397000
# <Task SGLFER3HKUT7Y7SNP4KN3TEH EXPORT_FEATURES: NDVI_2015_397000 (READY)>
# Cancelled task SGLFER3HKUT7Y7SNP4KN3TEH: NDVI_2015_397000
# <Task CQPS3HA6UK4YPBPJGEHKC36M EXPORT_FEATURES: NDVI_2014_397000 (READY)>
# Cancelled task CQPS3HA6UK4YPBPJGEHKC36M: NDVI_2014_397000
# <Task 4LQSXFNAJHP6SYNAFQZBXZ4U EXPORT_FEATURES: NDVI_2023_396000 (READY)>
# Cancelled task 4LQSXFNAJHP6SYNAFQZBXZ4U: NDVI_2023_396000
# <Task NEZ45KZOSRZR76SQHQ6JMHMH EXPORT_FEATURES: NDVI_2022_396000 (READY)>
# Cancelled task NEZ45KZOSRZR76SQHQ6JMHMH: NDVI_2022_396000
# <Task QLKTAX2MU76VQPEICQBIFOII EXPORT_FEATURES: NDVI_2021_396000 (READY)>
# Cancelled task QLKTAX2MU76VQPEICQBIFOII: NDVI_2021_396000
# <Task R77XIRCY4KJQJHWB5KK4BT42 EXPORT_FEATURES: NDVI_2020_396000 (READY)>
# Cancelled task R77XIRCY4KJQJHWB5KK4BT42: NDVI_2020_396000
# <Task 5VM6T7Y5WLSRWN6B5Y7NLBMD EXPORT_FEATURES: NDVI_2019_396000 (READY)>
# Cancelled task 5VM6T7Y5WLSRWN6B5Y7NLBMD: NDVI_2019_396000
# <Task OHJ56T5KP5Z74AP7N24OQXB7 EXPORT_FEATURES: NDVI_2018_396000 (READY)>
# Cancelled task OHJ56T5KP5Z74AP7N24OQXB7: NDVI_2018_396000
# <Task ZET5IEO6N324KAPSFLIDZBJ6 EXPORT_FEATURES: NDVI_2017_396000 (READY)>
# Cancelled task ZET5IEO6N324KAPSFLIDZBJ6: NDVI_2017_396000
# <Task NJTZQF2WQ357IRH6VFOYJFKD EXPORT_FEATURES: NDVI_2016_396000 (READY)>
# Cancelled task NJTZQF2WQ357IRH6VFOYJFKD: NDVI_2016_396000
# <Task UOQJSY5JXDY4E75CEI3LOC7B EXPORT_FEATURES: NDVI_2015_396000 (READY)>
# Cancelled task UOQJSY5JXDY4E75CEI3LOC7B: NDVI_2015_396000
# <Task QV77H7TJ76FFRVBWN2BSAOJO EXPORT_FEATURES: NDVI_2014_396000 (READY)>
# Cancelled task QV77H7TJ76FFRVBWN2BSAOJO: NDVI_2014_396000
# <Task QMULKPVIZLIUTYBBQANQSOC2 EXPORT_FEATURES: NDVI_2023_395000 (READY)>
# Cancelled task QMULKPVIZLIUTYBBQANQSOC2: NDVI_2023_395000
# <Task YNORWGDHZ2OKP4DCQH2NK5S5 EXPORT_FEATURES: NDVI_2022_395000 (READY)>
# Cancelled task YNORWGDHZ2OKP4DCQH2NK5S5: NDVI_2022_395000
# <Task L6MBAQU5F4UO6YEB6A2PTEBN EXPORT_FEATURES: NDVI_2021_395000 (READY)>
# Cancelled task L6MBAQU5F4UO6YEB6A2PTEBN: NDVI_2021_395000
# <Task QRL43LDHAKWJADHQFHEAK55B EXPORT_FEATURES: NDVI_2020_395000 (READY)>
# Cancelled task QRL43LDHAKWJADHQFHEAK55B: NDVI_2020_395000
# <Task 7GH26FP2UZ7547OHJUMRQEG5 EXPORT_FEATURES: NDVI_2019_395000 (READY)>
# Cancelled task 7GH26FP2UZ7547OHJUMRQEG5: NDVI_2019_395000
# <Task LU2A3ZOXHXIESH7HMG6U5AJF EXPORT_FEATURES: NDVI_2018_395000 (READY)>
# Cancelled task LU2A3ZOXHXIESH7HMG6U5AJF: NDVI_2018_395000
# <Task P73EFW4Z3Q776ZW5DHQ436GO EXPORT_FEATURES: NDVI_2017_395000 (READY)>
# Cancelled task P73EFW4Z3Q776ZW5DHQ436GO: NDVI_2017_395000
# <Task SKS6HC5GZKIUXYDWWEQLJI7T EXPORT_FEATURES: NDVI_2016_395000 (READY)>
# Cancelled task SKS6HC5GZKIUXYDWWEQLJI7T: NDVI_2016_395000
# <Task V7HWUKLLP5SQMEK4VX6Z56RS EXPORT_FEATURES: NDVI_2015_395000 (READY)>
# Cancelled task V7HWUKLLP5SQMEK4VX6Z56RS: NDVI_2015_395000
# <Task JZFLTQUZHZRVLG2LTQBA643W EXPORT_FEATURES: NDVI_2014_395000 (READY)>
# Cancelled task JZFLTQUZHZRVLG2LTQBA643W: NDVI_2014_395000
# <Task 4IAFMVINBN3B4LC6BOTBE4QN EXPORT_FEATURES: NDVI_2023_394000 (READY)>
# Cancelled task 4IAFMVINBN3B4LC6BOTBE4QN: NDVI_2023_394000
# <Task 5MS3JXJIXBR2YEAUHWOC3E32 EXPORT_FEATURES: NDVI_2022_394000 (READY)>
# Cancelled task 5MS3JXJIXBR2YEAUHWOC3E32: NDVI_2022_394000
# <Task AQRNHURZDMS55HXYVOT3JCHB EXPORT_FEATURES: NDVI_2021_394000 (READY)>
# Cancelled task AQRNHURZDMS55HXYVOT3JCHB: NDVI_2021_394000
# <Task TCZJ6CQMMBGFS56K3LBOMY3D EXPORT_FEATURES: NDVI_2020_394000 (READY)>
# Cancelled task TCZJ6CQMMBGFS56K3LBOMY3D: NDVI_2020_394000
# <Task ZTKHVBSAKSZWGGVRROMKG6NY EXPORT_FEATURES: NDVI_2019_394000 (READY)>
# Cancelled task ZTKHVBSAKSZWGGVRROMKG6NY: NDVI_2019_394000
# <Task QUPLK5MR3PODHNWO6JUNNVZA EXPORT_FEATURES: NDVI_2018_394000 (READY)>
# Cancelled task QUPLK5MR3PODHNWO6JUNNVZA: NDVI_2018_394000
# <Task T3WOI3QIIHI3ZMJMF46PNMGZ EXPORT_FEATURES: NDVI_2017_394000 (READY)>
# Cancelled task T3WOI3QIIHI3ZMJMF46PNMGZ: NDVI_2017_394000
# <Task RQYQY42JAVCPIPYWSXF77AWC EXPORT_FEATURES: NDVI_2016_394000 (READY)>
# Cancelled task RQYQY42JAVCPIPYWSXF77AWC: NDVI_2016_394000
# <Task ILWU7FETPVVKBKWJD32C7YE4 EXPORT_FEATURES: NDVI_2015_394000 (READY)>
# Cancelled task ILWU7FETPVVKBKWJD32C7YE4: NDVI_2015_394000
# <Task 2PEGUKJEWHCHZP7X3NX6EJP4 EXPORT_FEATURES: NDVI_2014_394000 (READY)>
# Cancelled task 2PEGUKJEWHCHZP7X3NX6EJP4: NDVI_2014_394000
# <Task SWCZTYX66VLDZNRRCBS7WRQG EXPORT_FEATURES: NDVI_2023_393000 (READY)>
# Cancelled task SWCZTYX66VLDZNRRCBS7WRQG: NDVI_2023_393000
# <Task GHDEZUATQPVZL4J3OOMTAUH6 EXPORT_FEATURES: NDVI_2022_393000 (READY)>
# Cancelled task GHDEZUATQPVZL4J3OOMTAUH6: NDVI_2022_393000
# <Task S2UNBATVUTPL2KMQ7HGDPVPW EXPORT_FEATURES: NDVI_2021_393000 (READY)>
# Cancelled task S2UNBATVUTPL2KMQ7HGDPVPW: NDVI_2021_393000
# <Task 3VCN3GMO2PHK4L2Q2W5NJNDR EXPORT_FEATURES: NDVI_2020_393000 (READY)>
# Cancelled task 3VCN3GMO2PHK4L2Q2W5NJNDR: NDVI_2020_393000
# <Task DGY2JYNTFWJNCH5ZAREJELRT EXPORT_FEATURES: NDVI_2019_393000 (READY)>
# Cancelled task DGY2JYNTFWJNCH5ZAREJELRT: NDVI_2019_393000
# <Task CARHK2K2L2QS57RFLEDGXPKG EXPORT_FEATURES: NDVI_2018_393000 (READY)>
# Cancelled task CARHK2K2L2QS57RFLEDGXPKG: NDVI_2018_393000
# <Task CZNJGUSBEPJNZWZEYSBOESWZ EXPORT_FEATURES: NDVI_2017_393000 (READY)>
# Cancelled task CZNJGUSBEPJNZWZEYSBOESWZ: NDVI_2017_393000
# <Task 3JAA5MVAXOHP5ITU34OY5LXZ EXPORT_FEATURES: NDVI_2016_393000 (READY)>
# Cancelled task 3JAA5MVAXOHP5ITU34OY5LXZ: NDVI_2016_393000
# <Task BCI4POD52FRRVNFBVCJRH6TG EXPORT_FEATURES: NDVI_2015_393000 (READY)>
# Cancelled task BCI4POD52FRRVNFBVCJRH6TG: NDVI_2015_393000
# <Task YBSKZPRIF3JDOVAEIX3VQ3YL EXPORT_FEATURES: NDVI_2014_393000 (READY)>
# Cancelled task YBSKZPRIF3JDOVAEIX3VQ3YL: NDVI_2014_393000
# <Task ZNC2ZVGXBWF4FL4VFIVOKPQY EXPORT_FEATURES: NDVI_2023_392000 (READY)>
# Cancelled task ZNC2ZVGXBWF4FL4VFIVOKPQY: NDVI_2023_392000
# <Task VAKZHEWJFZODA5R2AUT7BAAU EXPORT_FEATURES: NDVI_2022_392000 (READY)>
# Cancelled task VAKZHEWJFZODA5R2AUT7BAAU: NDVI_2022_392000
# <Task 7QFE75E527QFPTTGTGU5CER6 EXPORT_FEATURES: NDVI_2021_392000 (READY)>
# Cancelled task 7QFE75E527QFPTTGTGU5CER6: NDVI_2021_392000
# <Task VW4FX6DRSFI2SIUCHRHJ72GG EXPORT_FEATURES: NDVI_2020_392000 (READY)>
# Cancelled task VW4FX6DRSFI2SIUCHRHJ72GG: NDVI_2020_392000
# <Task 6JJI6CFN6HFKN4UW74UFXQ3X EXPORT_FEATURES: NDVI_2019_392000 (READY)>
# Cancelled task 6JJI6CFN6HFKN4UW74UFXQ3X: NDVI_2019_392000
# <Task 5GWHDB6GHGIKAOLZCNHZYI74 EXPORT_FEATURES: NDVI_2018_392000 (READY)>
# Cancelled task 5GWHDB6GHGIKAOLZCNHZYI74: NDVI_2018_392000
# <Task RVBHUWBZ4GGXWOGHZQICNKGG EXPORT_FEATURES: NDVI_2017_392000 (READY)>
# Cancelled task RVBHUWBZ4GGXWOGHZQICNKGG: NDVI_2017_392000
# <Task YLWO3MPMY5JKKRDEHRCQSUIX EXPORT_FEATURES: NDVI_2016_392000 (READY)>
# Cancelled task YLWO3MPMY5JKKRDEHRCQSUIX: NDVI_2016_392000
# <Task WKI6Y32JAG6FGWOYOBINZSGV EXPORT_FEATURES: NDVI_2015_392000 (READY)>
# Cancelled task WKI6Y32JAG6FGWOYOBINZSGV: NDVI_2015_392000
# <Task JY5AU6FNPN2O24SGEMLAKF47 EXPORT_FEATURES: NDVI_2014_392000 (READY)>
# Cancelled task JY5AU6FNPN2O24SGEMLAKF47: NDVI_2014_392000
# <Task 2H36DIH2VOXJ2GVPZKLQML4B EXPORT_FEATURES: NDVI_2023_391000 (READY)>
# Cancelled task 2H36DIH2VOXJ2GVPZKLQML4B: NDVI_2023_391000
# <Task XNQDKX2O5X6OS6UN2PBPHOLL EXPORT_FEATURES: NDVI_2022_391000 (READY)>
# Cancelled task XNQDKX2O5X6OS6UN2PBPHOLL: NDVI_2022_391000
# <Task TYTNGL4323M6OZT3OYKDEGX4 EXPORT_FEATURES: NDVI_2021_391000 (READY)>
# Cancelled task TYTNGL4323M6OZT3OYKDEGX4: NDVI_2021_391000
# <Task LX6MDXVVWJJFQRZNH3S2AQ6V EXPORT_FEATURES: NDVI_2020_391000 (READY)>
# Cancelled task LX6MDXVVWJJFQRZNH3S2AQ6V: NDVI_2020_391000
# <Task GHMNA5QGY257DVT3F5YXL3UQ EXPORT_FEATURES: NDVI_2019_391000 (READY)>
# Cancelled task GHMNA5QGY257DVT3F5YXL3UQ: NDVI_2019_391000
# <Task AC47N4VB3KQ6KR4EQOV52IJY EXPORT_FEATURES: NDVI_2018_391000 (READY)>
# Cancelled task AC47N4VB3KQ6KR4EQOV52IJY: NDVI_2018_391000
# <Task HIW6NUBZWTRZAQBNZOFV4QJA EXPORT_FEATURES: NDVI_2017_391000 (READY)>
# Cancelled task HIW6NUBZWTRZAQBNZOFV4QJA: NDVI_2017_391000
# <Task 2UTHX7XUCJFLTLZSO2G7QYZX EXPORT_FEATURES: NDVI_2016_391000 (READY)>
# Cancelled task 2UTHX7XUCJFLTLZSO2G7QYZX: NDVI_2016_391000
# <Task VAP2ITQ5FV6OB3N34P33SRWV EXPORT_FEATURES: NDVI_2015_391000 (READY)>
# Cancelled task VAP2ITQ5FV6OB3N34P33SRWV: NDVI_2015_391000
# <Task FL3JEMUWG2HFJFNGLK2O6MXS EXPORT_FEATURES: NDVI_2014_391000 (READY)>
# Cancelled task FL3JEMUWG2HFJFNGLK2O6MXS: NDVI_2014_391000
# <Task DTUSZD3GOHLNZS6UZN6DBPCR EXPORT_FEATURES: NDVI_2023_390000 (READY)>
# Cancelled task DTUSZD3GOHLNZS6UZN6DBPCR: NDVI_2023_390000
# <Task CDPVBXAOWVWPRTON7645PXBE EXPORT_FEATURES: NDVI_2022_390000 (READY)>
# Cancelled task CDPVBXAOWVWPRTON7645PXBE: NDVI_2022_390000
# <Task NRUSQHGIVNF6DQVU5HWVQKWE EXPORT_FEATURES: NDVI_2021_390000 (READY)>
# Cancelled task NRUSQHGIVNF6DQVU5HWVQKWE: NDVI_2021_390000
# <Task NIMVVFYWRG6UVKRACS6RK3MJ EXPORT_FEATURES: NDVI_2020_390000 (READY)>
# Cancelled task NIMVVFYWRG6UVKRACS6RK3MJ: NDVI_2020_390000
# <Task SZCXR3EUOGAGZ7KSISBPS3SA EXPORT_FEATURES: NDVI_2019_390000 (READY)>
# Cancelled task SZCXR3EUOGAGZ7KSISBPS3SA: NDVI_2019_390000
# <Task R25SEX6CK7O7MRDHCC3377QM EXPORT_FEATURES: NDVI_2018_390000 (READY)>
# Cancelled task R25SEX6CK7O7MRDHCC3377QM: NDVI_2018_390000
# <Task YD44SLU3X36CAV727HULN6JI EXPORT_FEATURES: NDVI_2017_390000 (READY)>
# Cancelled task YD44SLU3X36CAV727HULN6JI: NDVI_2017_390000
# <Task EHDSEPFGZBRWRG2SXP23TLJE EXPORT_FEATURES: NDVI_2016_390000 (READY)>
# Cancelled task EHDSEPFGZBRWRG2SXP23TLJE: NDVI_2016_390000
# <Task OCVEH4XADPJMAUXD6Z3XX7LH EXPORT_FEATURES: NDVI_2015_390000 (READY)>
# Cancelled task OCVEH4XADPJMAUXD6Z3XX7LH: NDVI_2015_390000
# <Task XJEHDA4GRFKW6GX2GD6CC2LF EXPORT_FEATURES: NDVI_2014_390000 (READY)>
# Cancelled task XJEHDA4GRFKW6GX2GD6CC2LF: NDVI_2014_390000
# <Task 722NWHHSDSRVRANBK5MBZDDM EXPORT_FEATURES: NDVI_2023_389000 (READY)>
# Cancelled task 722NWHHSDSRVRANBK5MBZDDM: NDVI_2023_389000
# <Task SNKLTKLSESUP433LRSK4CWS5 EXPORT_FEATURES: NDVI_2022_389000 (READY)>
# Cancelled task SNKLTKLSESUP433LRSK4CWS5: NDVI_2022_389000
# <Task NGI7XCYQZZLCDLQTJ2NL5MBW EXPORT_FEATURES: NDVI_2021_389000 (READY)>
# Cancelled task NGI7XCYQZZLCDLQTJ2NL5MBW: NDVI_2021_389000
# <Task 64574JJ46G2U5IC4HNX3NN5M EXPORT_FEATURES: NDVI_2020_389000 (READY)>
# Cancelled task 64574JJ46G2U5IC4HNX3NN5M: NDVI_2020_389000
# <Task XF2NEZ2HC3SPRDAOS72AY6EZ EXPORT_FEATURES: NDVI_2019_389000 (READY)>
# Cancelled task XF2NEZ2HC3SPRDAOS72AY6EZ: NDVI_2019_389000
# <Task DR6FNMIEK6QD7TWUOUP4T7CU EXPORT_FEATURES: NDVI_2018_389000 (READY)>
# Cancelled task DR6FNMIEK6QD7TWUOUP4T7CU: NDVI_2018_389000
# <Task KHXJXTRJXKE5R4UCSPMR35I4 EXPORT_FEATURES: NDVI_2017_389000 (READY)>
# Cancelled task KHXJXTRJXKE5R4UCSPMR35I4: NDVI_2017_389000
# <Task RXY7N2UTLL5WIUTOP52FC232 EXPORT_FEATURES: NDVI_2016_389000 (READY)>
# Cancelled task RXY7N2UTLL5WIUTOP52FC232: NDVI_2016_389000
# <Task VX5AIQCGQ5YBHNZAU32DA6WA EXPORT_FEATURES: NDVI_2015_389000 (READY)>
# Cancelled task VX5AIQCGQ5YBHNZAU32DA6WA: NDVI_2015_389000
# <Task MUSPLEQ5CR56OYAULLJCV2OW EXPORT_FEATURES: NDVI_2014_389000 (READY)>
# Cancelled task MUSPLEQ5CR56OYAULLJCV2OW: NDVI_2014_389000
# <Task 5SDRGQ5LJNKAYTKDB5YWGU7G EXPORT_FEATURES: NDVI_2023_388000 (READY)>
# Cancelled task 5SDRGQ5LJNKAYTKDB5YWGU7G: NDVI_2023_388000
# <Task DDRELI3OU6M6T3PM7NOXUFWJ EXPORT_FEATURES: NDVI_2022_388000 (READY)>
# Cancelled task DDRELI3OU6M6T3PM7NOXUFWJ: NDVI_2022_388000
# <Task AAWDK2F43TZ46DHFG5DZZM65 EXPORT_FEATURES: NDVI_2021_388000 (READY)>
# Cancelled task AAWDK2F43TZ46DHFG5DZZM65: NDVI_2021_388000
# <Task B3OA4H374OUZEK3VVQJ6VI73 EXPORT_FEATURES: NDVI_2020_388000 (READY)>
# Cancelled task B3OA4H374OUZEK3VVQJ6VI73: NDVI_2020_388000
# <Task X7PRBELRDVKWLO6SMLKMVTTJ EXPORT_FEATURES: NDVI_2019_388000 (READY)>
# Cancelled task X7PRBELRDVKWLO6SMLKMVTTJ: NDVI_2019_388000
# <Task SEUYULZJ2GESJZG3M5V6OPHY EXPORT_FEATURES: NDVI_2018_388000 (READY)>
# Cancelled task SEUYULZJ2GESJZG3M5V6OPHY: NDVI_2018_388000
# <Task KEG4JNDTNC63AKVNPFBCTLBX EXPORT_FEATURES: NDVI_2017_388000 (READY)>
# Cancelled task KEG4JNDTNC63AKVNPFBCTLBX: NDVI_2017_388000
# <Task CCC6ELZSRXLMVMOYXLHLENTR EXPORT_FEATURES: NDVI_2016_388000 (READY)>
# Cancelled task CCC6ELZSRXLMVMOYXLHLENTR: NDVI_2016_388000
# <Task JQB24OXMBNGFEE45JPJXICS3 EXPORT_FEATURES: NDVI_2015_388000 (READY)>
# Cancelled task JQB24OXMBNGFEE45JPJXICS3: NDVI_2015_388000
# <Task WGF5BU2F2T4JQADYWANBJG7H EXPORT_FEATURES: NDVI_2014_388000 (READY)>
# Cancelled task WGF5BU2F2T4JQADYWANBJG7H: NDVI_2014_388000
# <Task LF3CVYQOTPLJBMNCVO6MYZ7D EXPORT_FEATURES: NDVI_2023_387000 (READY)>
# Cancelled task LF3CVYQOTPLJBMNCVO6MYZ7D: NDVI_2023_387000
# <Task OC2PD3TJJFUS6ZICFH2XZR3A EXPORT_FEATURES: NDVI_2022_387000 (READY)>
# Cancelled task OC2PD3TJJFUS6ZICFH2XZR3A: NDVI_2022_387000
# <Task 6PRWTJMFCRXYWPODYGFOJUJO EXPORT_FEATURES: NDVI_2021_387000 (READY)>
# Cancelled task 6PRWTJMFCRXYWPODYGFOJUJO: NDVI_2021_387000
# <Task QUYURET3FVQQWMLK5B56MGQB EXPORT_FEATURES: NDVI_2020_387000 (READY)>
# Cancelled task QUYURET3FVQQWMLK5B56MGQB: NDVI_2020_387000
# <Task SVF67F7U4XS7HHT35SYYTMD4 EXPORT_FEATURES: NDVI_2019_387000 (READY)>
# Cancelled task SVF67F7U4XS7HHT35SYYTMD4: NDVI_2019_387000
# <Task QCA6HHG766HDUE5RI7XYVZOQ EXPORT_FEATURES: NDVI_2018_387000 (READY)>
# Cancelled task QCA6HHG766HDUE5RI7XYVZOQ: NDVI_2018_387000
# <Task 65EHGC63AS7ZWLZHJ2MR5NS3 EXPORT_FEATURES: NDVI_2017_387000 (READY)>
# Cancelled task 65EHGC63AS7ZWLZHJ2MR5NS3: NDVI_2017_387000
# <Task RRIA4D2B6XWLM43IRNTCXNV6 EXPORT_FEATURES: NDVI_2016_387000 (READY)>
# Cancelled task RRIA4D2B6XWLM43IRNTCXNV6: NDVI_2016_387000
# <Task KSPLO35UCD2YJN5DQ2ZRQVVL EXPORT_FEATURES: NDVI_2015_387000 (READY)>
# Cancelled task KSPLO35UCD2YJN5DQ2ZRQVVL: NDVI_2015_387000
# <Task ARMRVUTWJKSH3KBEIUKK3RCV EXPORT_FEATURES: NDVI_2014_387000 (READY)>
# Cancelled task ARMRVUTWJKSH3KBEIUKK3RCV: NDVI_2014_387000
# <Task 3WTOZQN5G3VXGVHEKQK4UJIT EXPORT_FEATURES: NDVI_2023_386000 (READY)>
# Cancelled task 3WTOZQN5G3VXGVHEKQK4UJIT: NDVI_2023_386000
# <Task IXZZBDR2AUWU55BHJTBTMPET EXPORT_FEATURES: NDVI_2022_386000 (READY)>
# Cancelled task IXZZBDR2AUWU55BHJTBTMPET: NDVI_2022_386000
# <Task EVKNKEZMGXDJTGU3GRL5B5WC EXPORT_FEATURES: NDVI_2021_386000 (READY)>
# Cancelled task EVKNKEZMGXDJTGU3GRL5B5WC: NDVI_2021_386000
# <Task CCLN2MRCWV4D5GN5HBBARAUC EXPORT_FEATURES: NDVI_2020_386000 (READY)>
# Cancelled task CCLN2MRCWV4D5GN5HBBARAUC: NDVI_2020_386000
# <Task C4E4K3BKJJPZJXWAK74PQ6SC EXPORT_FEATURES: NDVI_2019_386000 (READY)>
# Cancelled task C4E4K3BKJJPZJXWAK74PQ6SC: NDVI_2019_386000
# <Task BOOID67Z4QK6EJVR2QAC75QV EXPORT_FEATURES: NDVI_2018_386000 (READY)>
# Cancelled task BOOID67Z4QK6EJVR2QAC75QV: NDVI_2018_386000
# <Task PMSHO7JI4KX2SNPZ4CHNKY6P EXPORT_FEATURES: NDVI_2017_386000 (READY)>
# Cancelled task PMSHO7JI4KX2SNPZ4CHNKY6P: NDVI_2017_386000
# <Task FZLFJJSCO2AZBQUAYYN7ECQR EXPORT_FEATURES: NDVI_2016_386000 (READY)>
# Cancelled task FZLFJJSCO2AZBQUAYYN7ECQR: NDVI_2016_386000
# <Task B77I5TIW5FERVRIIG4K2I7VW EXPORT_FEATURES: NDVI_2015_386000 (READY)>
# Cancelled task B77I5TIW5FERVRIIG4K2I7VW: NDVI_2015_386000
# <Task IZIWEKMAE5FYOOHCI7M6QYGD EXPORT_FEATURES: NDVI_2014_386000 (READY)>
# Cancelled task IZIWEKMAE5FYOOHCI7M6QYGD: NDVI_2014_386000
# <Task NLSUUAQRUTPGNNYT7EXOSDGU EXPORT_FEATURES: NDVI_2023_385000 (READY)>
# Cancelled task NLSUUAQRUTPGNNYT7EXOSDGU: NDVI_2023_385000
# <Task 4WBQ7DWXGKUVIWMRL34GXUWH EXPORT_FEATURES: NDVI_2022_385000 (READY)>
# Cancelled task 4WBQ7DWXGKUVIWMRL34GXUWH: NDVI_2022_385000
# <Task IBL363ENM2KSNVOX22UKKJCU EXPORT_FEATURES: NDVI_2021_385000 (READY)>
# Cancelled task IBL363ENM2KSNVOX22UKKJCU: NDVI_2021_385000
# <Task ZF7IBCLR4724ASHX2UOI4OHB EXPORT_FEATURES: NDVI_2020_385000 (READY)>
# Cancelled task ZF7IBCLR4724ASHX2UOI4OHB: NDVI_2020_385000
# <Task SX7ENG6BWOEIBNWTNKBWSEPL EXPORT_FEATURES: NDVI_2019_385000 (READY)>
# Cancelled task SX7ENG6BWOEIBNWTNKBWSEPL: NDVI_2019_385000
# <Task XHEZFK3PFEEU6FWLHCXD4OBH EXPORT_FEATURES: NDVI_2018_385000 (READY)>
# Cancelled task XHEZFK3PFEEU6FWLHCXD4OBH: NDVI_2018_385000
# <Task M5JNHFSQTJ5MGMK3PJT2AYX2 EXPORT_FEATURES: NDVI_2017_385000 (READY)>
# Cancelled task M5JNHFSQTJ5MGMK3PJT2AYX2: NDVI_2017_385000
# <Task L6IXNDQEBDCVR7BKRFXFG6OZ EXPORT_FEATURES: NDVI_2016_385000 (READY)>
# Cancelled task L6IXNDQEBDCVR7BKRFXFG6OZ: NDVI_2016_385000
# <Task AO5NZR4FS6FZS4W44QKOBYZU EXPORT_FEATURES: NDVI_2015_385000 (READY)>
# Cancelled task AO5NZR4FS6FZS4W44QKOBYZU: NDVI_2015_385000
# <Task Y7ND4QO4UDTNPGMYDKB3BI4R EXPORT_FEATURES: NDVI_2014_385000 (READY)>
# Cancelled task Y7ND4QO4UDTNPGMYDKB3BI4R: NDVI_2014_385000
# <Task L32MVLLKEU5SH76JERYA73ZB EXPORT_FEATURES: NDVI_2023_384000 (READY)>
# Cancelled task L32MVLLKEU5SH76JERYA73ZB: NDVI_2023_384000
# <Task EUJE3V6H5KUDDM2DC5BO6RRL EXPORT_FEATURES: NDVI_2022_384000 (READY)>
# Cancelled task EUJE3V6H5KUDDM2DC5BO6RRL: NDVI_2022_384000
# <Task DVFSDDR43WGT2FPIHGMPHQWR EXPORT_FEATURES: NDVI_2021_384000 (READY)>
# Cancelled task DVFSDDR43WGT2FPIHGMPHQWR: NDVI_2021_384000
# <Task DWILUQUK4C46RQ7N2JTAHVAT EXPORT_FEATURES: NDVI_2020_384000 (READY)>
# Cancelled task DWILUQUK4C46RQ7N2JTAHVAT: NDVI_2020_384000
# <Task KHJZEMXGKICJIW6SKKKZ4DNR EXPORT_FEATURES: NDVI_2019_384000 (READY)>
# Cancelled task KHJZEMXGKICJIW6SKKKZ4DNR: NDVI_2019_384000
# <Task U2WTNSRKXZPG76YMWEOMV3DZ EXPORT_FEATURES: NDVI_2018_384000 (READY)>
# Cancelled task U2WTNSRKXZPG76YMWEOMV3DZ: NDVI_2018_384000
# <Task FWSG3LKO4VJ6ZD4I4NF4ZOQY EXPORT_FEATURES: NDVI_2017_384000 (READY)>
# Cancelled task FWSG3LKO4VJ6ZD4I4NF4ZOQY: NDVI_2017_384000
# <Task OGRDMBAXDWMMKXCHUFWTABWT EXPORT_FEATURES: NDVI_2016_384000 (READY)>
# Cancelled task OGRDMBAXDWMMKXCHUFWTABWT: NDVI_2016_384000
# <Task LSDRF3ZB3DWQYF6ZFDCVX24G EXPORT_FEATURES: NDVI_2015_384000 (READY)>
# Cancelled task LSDRF3ZB3DWQYF6ZFDCVX24G: NDVI_2015_384000
# <Task WGF7KQUKBWEYI6YZAELZEMFL EXPORT_FEATURES: NDVI_2014_384000 (READY)>
# Cancelled task WGF7KQUKBWEYI6YZAELZEMFL: NDVI_2014_384000
# <Task T3SVW3UJESZASADNMFT7Z6OQ EXPORT_FEATURES: NDVI_2023_383000 (READY)>
# Cancelled task T3SVW3UJESZASADNMFT7Z6OQ: NDVI_2023_383000
# <Task A4PXZ7JYJKDTXZ2WS35DFAKN EXPORT_FEATURES: NDVI_2022_383000 (READY)>
# Cancelled task A4PXZ7JYJKDTXZ2WS35DFAKN: NDVI_2022_383000
# <Task BUPAXVWP537MCZTQDDTTSBV5 EXPORT_FEATURES: NDVI_2021_383000 (READY)>
# Cancelled task BUPAXVWP537MCZTQDDTTSBV5: NDVI_2021_383000
# <Task ACSH3ORJ7J5W7AAZBZ4TRXUN EXPORT_FEATURES: NDVI_2020_383000 (READY)>
# Cancelled task ACSH3ORJ7J5W7AAZBZ4TRXUN: NDVI_2020_383000
# <Task HQPMO5PKT5366CMGFANDUMY7 EXPORT_FEATURES: NDVI_2019_383000 (READY)>
# Cancelled task HQPMO5PKT5366CMGFANDUMY7: NDVI_2019_383000
# <Task T3R3CVB62A6AK2WBFTMUYRQU EXPORT_FEATURES: NDVI_2018_383000 (READY)>
# Cancelled task T3R3CVB62A6AK2WBFTMUYRQU: NDVI_2018_383000
# <Task 5QARPJHNOPPJDB5UJ4A7Z3DR EXPORT_FEATURES: NDVI_2017_383000 (READY)>
# Cancelled task 5QARPJHNOPPJDB5UJ4A7Z3DR: NDVI_2017_383000
# <Task 5NIMF7CXZ6YQ4VBMA6TLXRBI EXPORT_FEATURES: NDVI_2016_383000 (READY)>
# Cancelled task 5NIMF7CXZ6YQ4VBMA6TLXRBI: NDVI_2016_383000
# <Task VAEJZ5YX3ERA3IF6O6W2MAR2 EXPORT_FEATURES: NDVI_2015_383000 (READY)>
# Cancelled task VAEJZ5YX3ERA3IF6O6W2MAR2: NDVI_2015_383000
# <Task AGBEMHQ3S4NHWAHUKRTAJQYP EXPORT_FEATURES: NDVI_2014_383000 (READY)>
# Cancelled task AGBEMHQ3S4NHWAHUKRTAJQYP: NDVI_2014_383000
# <Task OMCSFDHIBPXUISJ7MMJEKY3U EXPORT_FEATURES: NDVI_2023_382000 (READY)>
# Cancelled task OMCSFDHIBPXUISJ7MMJEKY3U: NDVI_2023_382000
# <Task HNP5QNE5B3L5ENH2CCANWUUN EXPORT_FEATURES: NDVI_2022_382000 (READY)>
# Cancelled task HNP5QNE5B3L5ENH2CCANWUUN: NDVI_2022_382000
# <Task NP5PFQHH7BCPQFKCXJYYGW2S EXPORT_FEATURES: NDVI_2021_382000 (READY)>
# Cancelled task NP5PFQHH7BCPQFKCXJYYGW2S: NDVI_2021_382000
# <Task VHAEVXX7HEVAL6XYTW3N72ZR EXPORT_FEATURES: NDVI_2020_382000 (READY)>
# Cancelled task VHAEVXX7HEVAL6XYTW3N72ZR: NDVI_2020_382000
# <Task DQHGZVGK6HVS4I7BXRNAWQGV EXPORT_FEATURES: NDVI_2019_382000 (READY)>
# Cancelled task DQHGZVGK6HVS4I7BXRNAWQGV: NDVI_2019_382000
# <Task GDARRMLDACJUDF6SJKFB6VP7 EXPORT_FEATURES: NDVI_2018_382000 (READY)>
# Cancelled task GDARRMLDACJUDF6SJKFB6VP7: NDVI_2018_382000
# <Task KPETVC7JBI7B7I4Y7IGKU3EF EXPORT_FEATURES: NDVI_2017_382000 (READY)>
# Cancelled task KPETVC7JBI7B7I4Y7IGKU3EF: NDVI_2017_382000
# <Task LVXEVEA3SFGG3K2M52PW6QC7 EXPORT_FEATURES: NDVI_2016_382000 (READY)>
# Cancelled task LVXEVEA3SFGG3K2M52PW6QC7: NDVI_2016_382000
# <Task ECMYDWCIHQNGP5PAS75SSXWS EXPORT_FEATURES: NDVI_2015_382000 (READY)>
# Cancelled task ECMYDWCIHQNGP5PAS75SSXWS: NDVI_2015_382000
# <Task HWJHW3RSHVW25JLUWRUN3SGM EXPORT_FEATURES: NDVI_2014_382000 (READY)>
# Cancelled task HWJHW3RSHVW25JLUWRUN3SGM: NDVI_2014_382000
# <Task EZJJMQODNB2O2VNXP5LE46JR EXPORT_FEATURES: NDVI_2023_381000 (READY)>
# Cancelled task EZJJMQODNB2O2VNXP5LE46JR: NDVI_2023_381000
# <Task HEE4D5XQA6JLEMV6OWAOASAK EXPORT_FEATURES: NDVI_2022_381000 (READY)>
# Cancelled task HEE4D5XQA6JLEMV6OWAOASAK: NDVI_2022_381000
# <Task 2PTOPXFJEJMJ6CGUKAKEETE7 EXPORT_FEATURES: NDVI_2021_381000 (READY)>
# Cancelled task 2PTOPXFJEJMJ6CGUKAKEETE7: NDVI_2021_381000
# <Task OTMNTT22TBYWDARKL3VZ2TPK EXPORT_FEATURES: NDVI_2020_381000 (READY)>
# Cancelled task OTMNTT22TBYWDARKL3VZ2TPK: NDVI_2020_381000
# <Task HXL22ZUD366BBIXGC4Q7PM6K EXPORT_FEATURES: NDVI_2019_381000 (READY)>
# Cancelled task HXL22ZUD366BBIXGC4Q7PM6K: NDVI_2019_381000
# <Task YR2PHRYE75MZN3WSLAIBYQSQ EXPORT_FEATURES: NDVI_2018_381000 (READY)>
# Cancelled task YR2PHRYE75MZN3WSLAIBYQSQ: NDVI_2018_381000
# <Task 6PNXYUQUDIQALRUZ55VMUPU2 EXPORT_FEATURES: NDVI_2017_381000 (READY)>
# Cancelled task 6PNXYUQUDIQALRUZ55VMUPU2: NDVI_2017_381000
# <Task VXF3FODX5VQO4HZCPARYJQU2 EXPORT_FEATURES: NDVI_2016_381000 (READY)>
# Cancelled task VXF3FODX5VQO4HZCPARYJQU2: NDVI_2016_381000
# <Task CPIIPGSZSWJJT4EGDPWYTKNT EXPORT_FEATURES: NDVI_2015_381000 (READY)>
# Cancelled task CPIIPGSZSWJJT4EGDPWYTKNT: NDVI_2015_381000
# <Task 2KCS6PWVI5NAGRBI5VY25OFF EXPORT_FEATURES: NDVI_2014_381000 (READY)>
# Cancelled task 2KCS6PWVI5NAGRBI5VY25OFF: NDVI_2014_381000
# <Task 43BSY2F2DIZDPHDMJJJBNNIV EXPORT_FEATURES: NDVI_2023_380000 (READY)>
# Cancelled task 43BSY2F2DIZDPHDMJJJBNNIV: NDVI_2023_380000
# <Task WGP43XHRV3P7KCGUBMF5GLN4 EXPORT_FEATURES: NDVI_2022_380000 (READY)>
# Cancelled task WGP43XHRV3P7KCGUBMF5GLN4: NDVI_2022_380000
# <Task JCSTWL6AHAEQ3L3UW5RNN7J4 EXPORT_FEATURES: NDVI_2021_380000 (READY)>
# Cancelled task JCSTWL6AHAEQ3L3UW5RNN7J4: NDVI_2021_380000
# <Task B2ZJBM23CGWC6WO4Y7FDHVES EXPORT_FEATURES: NDVI_2020_380000 (READY)>
# Cancelled task B2ZJBM23CGWC6WO4Y7FDHVES: NDVI_2020_380000
# <Task 3LNWBBQSQCTA6UPTXKSE3AFA EXPORT_FEATURES: NDVI_2019_380000 (READY)>
# Cancelled task 3LNWBBQSQCTA6UPTXKSE3AFA: NDVI_2019_380000
# <Task HCHY32UUWXYKXBUIN4PV5SF2 EXPORT_FEATURES: NDVI_2018_380000 (READY)>
# Cancelled task HCHY32UUWXYKXBUIN4PV5SF2: NDVI_2018_380000
# <Task OQOF62X26M6VPFLDY2T7USFY EXPORT_FEATURES: NDVI_2017_380000 (READY)>
# Cancelled task OQOF62X26M6VPFLDY2T7USFY: NDVI_2017_380000
# <Task L65B37VRT3TP7YP2FR52DES4 EXPORT_FEATURES: NDVI_2016_380000 (READY)>
# Cancelled task L65B37VRT3TP7YP2FR52DES4: NDVI_2016_380000
# <Task ONIIGB2DB4OS5HD2LSPE2TIE EXPORT_FEATURES: NDVI_2015_380000 (READY)>
# Cancelled task ONIIGB2DB4OS5HD2LSPE2TIE: NDVI_2015_380000
# <Task ASJOPWT4YVXPD6ZV735XFD2H EXPORT_FEATURES: NDVI_2014_380000 (READY)>
# Cancelled task ASJOPWT4YVXPD6ZV735XFD2H: NDVI_2014_380000
# <Task UIQTXKJLYBP6XZ5QNHVME56J EXPORT_FEATURES: NDVI_2023_379000 (READY)>
# Cancelled task UIQTXKJLYBP6XZ5QNHVME56J: NDVI_2023_379000
# <Task FNX5V4MT2MLHVRQR2PSJGVBQ EXPORT_FEATURES: NDVI_2022_379000 (READY)>
# Cancelled task FNX5V4MT2MLHVRQR2PSJGVBQ: NDVI_2022_379000
# <Task CBWZYG27GTUHDXVYCIY4DB3C EXPORT_FEATURES: NDVI_2021_379000 (READY)>
# Cancelled task CBWZYG27GTUHDXVYCIY4DB3C: NDVI_2021_379000
# <Task MCM4I5HNE2O52UGCNUMVZVY6 EXPORT_FEATURES: NDVI_2020_379000 (READY)>
# Cancelled task MCM4I5HNE2O52UGCNUMVZVY6: NDVI_2020_379000
# <Task S76MT2XNJU4CJ446MLOEKHKZ EXPORT_FEATURES: NDVI_2019_379000 (READY)>
# Cancelled task S76MT2XNJU4CJ446MLOEKHKZ: NDVI_2019_379000
# <Task CV7NIZX6OVSNZ7LCAULE7SKK EXPORT_FEATURES: NDVI_2018_379000 (READY)>
# Cancelled task CV7NIZX6OVSNZ7LCAULE7SKK: NDVI_2018_379000
# <Task EHXFCTRT6GGXIMWD3SS6EVLX EXPORT_FEATURES: NDVI_2017_379000 (READY)>
# Cancelled task EHXFCTRT6GGXIMWD3SS6EVLX: NDVI_2017_379000
# <Task TQFBFEPLSU4QKH2VDL72NV46 EXPORT_FEATURES: NDVI_2016_379000 (READY)>
# Cancelled task TQFBFEPLSU4QKH2VDL72NV46: NDVI_2016_379000
# <Task UVS7FINB4APCTWO5ZDBDGNLD EXPORT_FEATURES: NDVI_2015_379000 (READY)>
# Cancelled task UVS7FINB4APCTWO5ZDBDGNLD: NDVI_2015_379000
# <Task KE24N6QVEO73ZXAOPHD4JJX2 EXPORT_FEATURES: NDVI_2014_379000 (READY)>
# Cancelled task KE24N6QVEO73ZXAOPHD4JJX2: NDVI_2014_379000
# <Task P6HTXGMJMZ5K5QCKKEKZIPNQ EXPORT_FEATURES: NDVI_2023_378000 (READY)>
# Cancelled task P6HTXGMJMZ5K5QCKKEKZIPNQ: NDVI_2023_378000
# <Task L6URFV4SSH5KHQGNTYA5BYT6 EXPORT_FEATURES: NDVI_2022_378000 (READY)>
# Cancelled task L6URFV4SSH5KHQGNTYA5BYT6: NDVI_2022_378000
# <Task 56MG4RCMFPEZEHMG7LPJFX4W EXPORT_FEATURES: NDVI_2021_378000 (READY)>
# Cancelled task 56MG4RCMFPEZEHMG7LPJFX4W: NDVI_2021_378000
# <Task MTNEG7DQC4HMO3RWYLMCMEYN EXPORT_FEATURES: NDVI_2020_378000 (READY)>
# Cancelled task MTNEG7DQC4HMO3RWYLMCMEYN: NDVI_2020_378000
# <Task XW7HSRTVPYBPIOVGQ7IERLQP EXPORT_FEATURES: NDVI_2019_378000 (READY)>
# Cancelled task XW7HSRTVPYBPIOVGQ7IERLQP: NDVI_2019_378000
# <Task DSBVVYXVSTSLDGAFM3EAJF6F EXPORT_FEATURES: NDVI_2018_378000 (READY)>
# Cancelled task DSBVVYXVSTSLDGAFM3EAJF6F: NDVI_2018_378000
# <Task GK6JQPFZZ6SBFHEHRNLXMJA3 EXPORT_FEATURES: NDVI_2017_378000 (READY)>
# Cancelled task GK6JQPFZZ6SBFHEHRNLXMJA3: NDVI_2017_378000
# <Task JNRIQ2KGOPCHYAXMBVN6ONWR EXPORT_FEATURES: NDVI_2016_378000 (READY)>
# Cancelled task JNRIQ2KGOPCHYAXMBVN6ONWR: NDVI_2016_378000
# <Task 2GW5ZCBUMRXS6RLPF7YLSXKF EXPORT_FEATURES: NDVI_2015_378000 (READY)>
# Cancelled task 2GW5ZCBUMRXS6RLPF7YLSXKF: NDVI_2015_378000
# <Task PA3CPSVER2IIAW47HVMY4HKN EXPORT_FEATURES: NDVI_2014_378000 (READY)>
# Cancelled task PA3CPSVER2IIAW47HVMY4HKN: NDVI_2014_378000
# <Task 2KOVWNSHXYLDIJQ44KAF2EVB EXPORT_FEATURES: NDVI_2023_377000 (READY)>
# Cancelled task 2KOVWNSHXYLDIJQ44KAF2EVB: NDVI_2023_377000
# <Task WG6DHLVYXVFQXPY4F7P3TV6G EXPORT_FEATURES: NDVI_2022_377000 (READY)>
# Cancelled task WG6DHLVYXVFQXPY4F7P3TV6G: NDVI_2022_377000
# <Task Z4DG6TUBNAEUTDDRKETS7NRE EXPORT_FEATURES: NDVI_2021_377000 (READY)>
# Cancelled task Z4DG6TUBNAEUTDDRKETS7NRE: NDVI_2021_377000
# <Task 6IJBMO6VTMKIDFOXW4GX5YZP EXPORT_FEATURES: NDVI_2020_377000 (READY)>
# Cancelled task 6IJBMO6VTMKIDFOXW4GX5YZP: NDVI_2020_377000
# <Task 7PCEAJX4NRMCN5XDFDDCLRMW EXPORT_FEATURES: NDVI_2019_377000 (READY)>
# Cancelled task 7PCEAJX4NRMCN5XDFDDCLRMW: NDVI_2019_377000
# <Task 7HFRTQFL6I5GPL3CVQAJEXJL EXPORT_FEATURES: NDVI_2018_377000 (READY)>
# Cancelled task 7HFRTQFL6I5GPL3CVQAJEXJL: NDVI_2018_377000
# <Task DZ5VQQC2DFFYPNZ6DL6JHHSX EXPORT_FEATURES: NDVI_2017_377000 (READY)>
# Cancelled task DZ5VQQC2DFFYPNZ6DL6JHHSX: NDVI_2017_377000
# <Task LQRGUOSDW56ZCSCY7JFNBGI7 EXPORT_FEATURES: NDVI_2016_377000 (READY)>
# Cancelled task LQRGUOSDW56ZCSCY7JFNBGI7: NDVI_2016_377000
# <Task RA2COG5FDODLIT4FFLMPUCWC EXPORT_FEATURES: NDVI_2015_377000 (READY)>
# Cancelled task RA2COG5FDODLIT4FFLMPUCWC: NDVI_2015_377000
# <Task U3BKFKZR4H7K53DMJ6IDSARC EXPORT_FEATURES: NDVI_2014_377000 (READY)>
# Cancelled task U3BKFKZR4H7K53DMJ6IDSARC: NDVI_2014_377000
# <Task QTQU3ORIGF2RLXO2W3XB2CFU EXPORT_FEATURES: NDVI_2023_376000 (READY)>
# Cancelled task QTQU3ORIGF2RLXO2W3XB2CFU: NDVI_2023_376000
# <Task 254KABTH66NYPRQWN4X36PDN EXPORT_FEATURES: NDVI_2022_376000 (READY)>
# Cancelled task 254KABTH66NYPRQWN4X36PDN: NDVI_2022_376000
# <Task ZWNPBNG2QHOWI5WXX4VKLT5A EXPORT_FEATURES: NDVI_2021_376000 (READY)>
# Cancelled task ZWNPBNG2QHOWI5WXX4VKLT5A: NDVI_2021_376000
# <Task F23IXY6P76DNR7NJAOB4RHIZ EXPORT_FEATURES: NDVI_2020_376000 (READY)>
# Cancelled task F23IXY6P76DNR7NJAOB4RHIZ: NDVI_2020_376000
# <Task I46H3YEPADT5XAWI2RMSSQ6G EXPORT_FEATURES: NDVI_2019_376000 (READY)>
# Cancelled task I46H3YEPADT5XAWI2RMSSQ6G: NDVI_2019_376000
# <Task S33QOJISKNDKR7RKPZASIZ4K EXPORT_FEATURES: NDVI_2018_376000 (READY)>
# Cancelled task S33QOJISKNDKR7RKPZASIZ4K: NDVI_2018_376000
# <Task RU5LXURG5UA4NPF6ZO3USIXH EXPORT_FEATURES: NDVI_2017_376000 (READY)>
# Cancelled task RU5LXURG5UA4NPF6ZO3USIXH: NDVI_2017_376000
# <Task NAVV44XS46V2RAK245CAH23G EXPORT_FEATURES: NDVI_2016_376000 (READY)>
# Cancelled task NAVV44XS46V2RAK245CAH23G: NDVI_2016_376000
# <Task LY52GZMOEBWI6IX4LG2TE66I EXPORT_FEATURES: NDVI_2015_376000 (READY)>
# Cancelled task LY52GZMOEBWI6IX4LG2TE66I: NDVI_2015_376000
# <Task PXXUEPUT5AZFARCNYXLJSCE2 EXPORT_FEATURES: NDVI_2014_376000 (READY)>
# Cancelled task PXXUEPUT5AZFARCNYXLJSCE2: NDVI_2014_376000
# <Task SDYMY6VAVV7EGLL4SA6CA7PI EXPORT_FEATURES: NDVI_2023_375000 (READY)>
# Cancelled task SDYMY6VAVV7EGLL4SA6CA7PI: NDVI_2023_375000
# <Task N5YEPOIUSVDODVYP65GUYO73 EXPORT_FEATURES: NDVI_2022_375000 (READY)>
# Cancelled task N5YEPOIUSVDODVYP65GUYO73: NDVI_2022_375000
# <Task BXOEBCHI2EFXFDWPZXRDBQZE EXPORT_FEATURES: NDVI_2021_375000 (READY)>
# Cancelled task BXOEBCHI2EFXFDWPZXRDBQZE: NDVI_2021_375000
# <Task VQ5RZ433SQMUQDEHEM5IN2B4 EXPORT_FEATURES: NDVI_2020_375000 (READY)>
# Cancelled task VQ5RZ433SQMUQDEHEM5IN2B4: NDVI_2020_375000
# <Task V37GGT6QDLNO4A7SFL72QPAU EXPORT_FEATURES: NDVI_2019_375000 (READY)>
# Cancelled task V37GGT6QDLNO4A7SFL72QPAU: NDVI_2019_375000
# <Task JEKAGLNXRJNNIO2LLIHQATU6 EXPORT_FEATURES: NDVI_2018_375000 (READY)>
# Cancelled task JEKAGLNXRJNNIO2LLIHQATU6: NDVI_2018_375000
# <Task CYXL4A2CA2X35BV2G4LGA4C7 EXPORT_FEATURES: NDVI_2017_375000 (READY)>
# Cancelled task CYXL4A2CA2X35BV2G4LGA4C7: NDVI_2017_375000
# <Task 7BL3SVH6FF7TNPMGNKZ66FZF EXPORT_FEATURES: NDVI_2016_375000 (READY)>
# Cancelled task 7BL3SVH6FF7TNPMGNKZ66FZF: NDVI_2016_375000
# <Task EGDRFQ54NPHKWRPDWPUS3G7C EXPORT_FEATURES: NDVI_2015_375000 (READY)>
# Cancelled task EGDRFQ54NPHKWRPDWPUS3G7C: NDVI_2015_375000
# <Task XQY6GFDVGDGW4F2ZXA7X4N3B EXPORT_FEATURES: NDVI_2014_375000 (READY)>
# Cancelled task XQY6GFDVGDGW4F2ZXA7X4N3B: NDVI_2014_375000
# <Task OFEAMGRHBHHKJXFWVUUHHFPC EXPORT_FEATURES: NDVI_2023_374000 (READY)>
# Cancelled task OFEAMGRHBHHKJXFWVUUHHFPC: NDVI_2023_374000
# <Task Y3B4ALPNLOAEEJC36FJNMYV6 EXPORT_FEATURES: NDVI_2022_374000 (READY)>
# Cancelled task Y3B4ALPNLOAEEJC36FJNMYV6: NDVI_2022_374000
# <Task 2VKG4LRXKXSTVPARU3X3OXLQ EXPORT_FEATURES: NDVI_2021_374000 (READY)>
# Cancelled task 2VKG4LRXKXSTVPARU3X3OXLQ: NDVI_2021_374000
# <Task ZGNLOJJY46Z3G3EXPCKTHMP2 EXPORT_FEATURES: NDVI_2020_374000 (READY)>
# Cancelled task ZGNLOJJY46Z3G3EXPCKTHMP2: NDVI_2020_374000
# <Task 27B5NSATGYXOG423KT7UCJ4E EXPORT_FEATURES: NDVI_2019_374000 (READY)>
# Cancelled task 27B5NSATGYXOG423KT7UCJ4E: NDVI_2019_374000
# <Task NF6RPN5QCEIBG5KRASWLFC4S EXPORT_FEATURES: NDVI_2018_374000 (READY)>
# Cancelled task NF6RPN5QCEIBG5KRASWLFC4S: NDVI_2018_374000
# <Task O56HFK2HS4P5TKKKFDXEHASO EXPORT_FEATURES: NDVI_2017_374000 (READY)>
# Cancelled task O56HFK2HS4P5TKKKFDXEHASO: NDVI_2017_374000
# <Task I6JYUGTX6C34ZBXIZNQR7WIC EXPORT_FEATURES: NDVI_2016_374000 (READY)>
# Cancelled task I6JYUGTX6C34ZBXIZNQR7WIC: NDVI_2016_374000
# <Task BJHHDZEF22CUDBBJ4FPF7FQW EXPORT_FEATURES: NDVI_2015_374000 (READY)>
# Cancelled task BJHHDZEF22CUDBBJ4FPF7FQW: NDVI_2015_374000
# <Task PUNHAA3Z77RLUP5EJ3DCRCJF EXPORT_FEATURES: NDVI_2014_374000 (READY)>
# Cancelled task PUNHAA3Z77RLUP5EJ3DCRCJF: NDVI_2014_374000
# <Task WEHBU2PECPZRLV6PQENEBXYR EXPORT_FEATURES: NDVI_2023_373000 (READY)>
# Cancelled task WEHBU2PECPZRLV6PQENEBXYR: NDVI_2023_373000
# ...
# <Task CIIRXRFWUQL62KTWHUPE3VKN EXPORT_FEATURES: NDVI_2016_288000 (COMPLETED)>
# <Task JWBQWJT65QFWUNS3GYKWGKCP EXPORT_FEATURES: NDVI_2015_288000 (COMPLETED)>
# <Task 357T5T7CNRNWDOA2BM56OCSV EXPORT_FEATURES: NDVI_2014_288000 (COMPLETED)>
# <Task JZOGR6LFZKFZGQ3BK6DX4AB3 EXPORT_FEATURES: NDVI_2023_287000 (COMPLETED)>
# <Task 3YDLPI7QAYECT37DVK6ITJXL EXPORT_FEATURES: NDVI_2022_287000 (COMPLETED)>
# <Task I42YETALZV4HWCDYOMG2R3XJ EXPORT_FEATURES: NDVI_2021_287000 (COMPLETED)>
# <Task SI43MSJ2ZIZR5B6NLB5TRBI6 EXPORT_FEATURES: NDVI_2020_287000 (COMPLETED)>
# <Task LVEPGYHEW6UEHUQ4ORNOMCUR EXPORT_FEATURES: NDVI_2019_287000 (COMPLETED)>
# <Task BU6MF2QLLCQGXJHN6MU7AAUN EXPORT_FEATURES: NDVI_2018_287000 (COMPLETED)>
# <Task FIHWM4RTHQEHMIYXGUAXHAIA EXPORT_FEATURES: NDVI_2017_287000 (COMPLETED)>
# <Task OU6FGK3BTL7HWLXPCKFK2KTJ EXPORT_FEATURES: NDVI_2016_287000 (COMPLETED)>
# <Task JK4BIBECLUSCGQ2OPSWH355S EXPORT_FEATURES: NDVI_2015_287000 (COMPLETED)>
# <Task 6WNGADLNFC6VTIXGZMVM5M2I EXPORT_FEATURES: NDVI_2014_287000 (COMPLETED)>
# <Task ZABM3SXNYG3R5OMEVDFT3RYC EXPORT_FEATURES: NDVI_2023_286000 (COMPLETED)>
# <Task HT3C5UNG575PLCPCTOH2QK7G EXPORT_FEATURES: NDVI_2022_286000 (COMPLETED)>
# <Task U4U3RZOM4NJYDIX3XIRAHMIH EXPORT_FEATURES: NDVI_2021_286000 (COMPLETED)>
# <Task QU5GM6HYAN76HJGKKPG6HSJS EXPORT_FEATURES: NDVI_2020_286000 (COMPLETED)>
# <Task 2DMLV667DGU46K5EME23CL27 EXPORT_FEATURES: NDVI_2019_286000 (COMPLETED)>
# <Task CVDGIDDCB7VU5VUMZU6MLTEE EXPORT_FEATURES: NDVI_2018_286000 (COMPLETED)>
# <Task MV5EYZCZQFUTQORG32ZXBD5D EXPORT_FEATURES: NDVI_2017_286000 (COMPLETED)>
# <Task DD6FQX4XYKIQMTKZZBHPWXKC EXPORT_FEATURES: NDVI_2016_286000 (COMPLETED)>
# <Task GF3Y7QTOIAXF5SM2AS5XGH35 EXPORT_FEATURES: NDVI_2015_286000 (COMPLETED)>
# <Task CEMXKRLENG2APNAFBX2QVIJU EXPORT_FEATURES: NDVI_2014_286000 (COMPLETED)>
# <Task RCNRKPNWVRUV7T4YAA3HAQON EXPORT_FEATURES: NDVI_2023_285000 (COMPLETED)>
# <Task SMJB2KACDLQADOXXHL3JINNT EXPORT_FEATURES: NDVI_2022_285000 (COMPLETED)>
# <Task 5DR7WGI6T4P2YD66IMVNZ6EO EXPORT_FEATURES: NDVI_2021_285000 (COMPLETED)>
# <Task T7D6Z57724QBUEDRSN4EVNOI EXPORT_FEATURES: NDVI_2020_285000 (COMPLETED)>
# <Task WS7VZB4BWPBIGIBZAEGFRM3X EXPORT_FEATURES: NDVI_2019_285000 (COMPLETED)>
# <Task KW6FRDPI3DYULU234A2FFWH6 EXPORT_FEATURES: NDVI_2018_285000 (COMPLETED)>
# <Task GTQKOLQPKO764XOJ6OHQGTL7 EXPORT_FEATURES: NDVI_2017_285000 (COMPLETED)>
# <Task 2WHMKYRJSQZJ7AOZIOJNPETA EXPORT_FEATURES: NDVI_2016_285000 (COMPLETED)>
# <Task W27YIUOUXEKFPGOR6GBCYPAH EXPORT_FEATURES: NDVI_2015_285000 (COMPLETED)>
# <Task LEHQMMGORCB5UXWVBJQBSMZR EXPORT_FEATURES: NDVI_2014_285000 (COMPLETED)>
# <Task CBYIDCAXZN2TPSZFUZW6RHXM EXPORT_FEATURES: NDVI_2023_284000 (COMPLETED)>
# <Task UTY7BYTOEGOPSUNY4MBQMIWP EXPORT_FEATURES: NDVI_2022_284000 (COMPLETED)>
# <Task 2PUPSM5XUF2NXU6DGHMQFJ5G EXPORT_FEATURES: NDVI_2021_284000 (COMPLETED)>
# <Task DRZQRK6X7TBHLJQPEV6GR7RI EXPORT_FEATURES: NDVI_2020_284000 (COMPLETED)>
# <Task 365KCBHOYVZ67OA36TH4YD3U EXPORT_FEATURES: NDVI_2019_284000 (COMPLETED)>
# <Task G32COG5BFCKYAMKKB3OYPJSF EXPORT_FEATURES: NDVI_2018_284000 (COMPLETED)>
# <Task 4UAJAD5LKFRJRBI4JYQWWWXB EXPORT_FEATURES: NDVI_2017_284000 (COMPLETED)>
# <Task 5INXDHQMWT6JAHJSEMNLEVFI EXPORT_FEATURES: NDVI_2016_284000 (COMPLETED)>
# <Task 6PXHPGR3B7ILF32UT23YVFUZ EXPORT_FEATURES: NDVI_2015_284000 (COMPLETED)>
# <Task PGH33VBVDEQSDMCIPL7TWOLT EXPORT_FEATURES: NDVI_2014_284000 (COMPLETED)>
# <Task ZM4XWQNIQICVDP4JYUHB2JYK EXPORT_FEATURES: NDVI_2023_283000 (COMPLETED)>
# <Task 2VFNNQSDK5E6JLAWRHE77NVP EXPORT_FEATURES: NDVI_2022_283000 (COMPLETED)>
# <Task ZRRGBJD2EPSJ4RSNRQZ7NNSL EXPORT_FEATURES: NDVI_2021_283000 (COMPLETED)>
# <Task BVC5C7OZSA4P47VOFGK4JXEL EXPORT_FEATURES: NDVI_2020_283000 (COMPLETED)>
# <Task UBOMIQKQ3QJBXRLQ5HVMO57H EXPORT_FEATURES: NDVI_2019_283000 (COMPLETED)>
# <Task GF2AJFRJATZFPLLME7RFBSFI EXPORT_FEATURES: NDVI_2018_283000 (COMPLETED)>
# <Task OEVLQKMCBHAVAYXDYL62E73D EXPORT_FEATURES: NDVI_2017_283000 (COMPLETED)>
# <Task OWLAFC7YJCQ5QMG2S3MADITY EXPORT_FEATURES: NDVI_2016_283000 (COMPLETED)>
# <Task 2B64DX65DWG2TDSMF2G6TBZL EXPORT_FEATURES: NDVI_2015_283000 (COMPLETED)>
# <Task GLREFWHD6YIOWQZXPVO7FUNQ EXPORT_FEATURES: NDVI_2014_283000 (COMPLETED)>
# <Task BWRHMA5TA5JASKS5RB2DX3SV EXPORT_FEATURES: NDVI_2023_282000 (COMPLETED)>
# <Task Y5765QBZU6JAFZDGPFGZWBN7 EXPORT_FEATURES: NDVI_2022_282000 (COMPLETED)>
# <Task JPVLNN3FOJ62VL7WUETGFAOA EXPORT_FEATURES: NDVI_2021_282000 (COMPLETED)>
# <Task EK2BVNE5JDQIIDCWIKJBZXLI EXPORT_FEATURES: NDVI_2020_282000 (COMPLETED)>
# <Task RDEUIA7SWO5ULZGRQYYBHWFT EXPORT_FEATURES: NDVI_2019_282000 (COMPLETED)>
# <Task WKG6IQLGAGBJR3MDCT363IFG EXPORT_FEATURES: NDVI_2018_282000 (COMPLETED)>
# <Task IVIDOJ4JUGOSN4DED4XE4LQI EXPORT_FEATURES: NDVI_2017_282000 (COMPLETED)>
# <Task MP7BGEGQKA4BYNG2EPBHPJQP EXPORT_FEATURES: NDVI_2016_282000 (COMPLETED)>
# <Task CTEQKTAWADNYXBRMDOJQ3YKL EXPORT_FEATURES: NDVI_2015_282000 (COMPLETED)>
# <Task PW7GZ7J2KP2RJMZMSTYMFHS5 EXPORT_FEATURES: NDVI_2014_282000 (COMPLETED)>
# <Task SG5UDI4B4EI425ZUREJ4OLFI EXPORT_FEATURES: NDVI_2023_281000 (COMPLETED)>
# <Task I5DX2XVH4RJWDDNDJOTLCELI EXPORT_FEATURES: NDVI_2022_281000 (COMPLETED)>
# <Task YEZZBFJ22SFTIRMR4TJM4DDO EXPORT_FEATURES: NDVI_2021_281000 (COMPLETED)>
# <Task 2UDJDVAJ453IHAGQOMXIP4K5 EXPORT_FEATURES: NDVI_2020_281000 (COMPLETED)>
# <Task NQHHQ3V576K44CDO7JE53JXB EXPORT_FEATURES: NDVI_2019_281000 (COMPLETED)>
# <Task 4DSEHCTUCUUCP7ETMPXZIMQI EXPORT_FEATURES: NDVI_2018_281000 (COMPLETED)>
# <Task KBNN2ODRFQZNGN3EQPD3FUE7 EXPORT_FEATURES: NDVI_2017_281000 (COMPLETED)>
# <Task KTOOWIADCPDVTRSIYWELMI4O EXPORT_FEATURES: NDVI_2016_281000 (COMPLETED)>
# <Task NH57PCZREXUIBTV7WSKN62FK EXPORT_FEATURES: NDVI_2015_281000 (COMPLETED)>
# <Task ZOM6CEEJRXOU3EMNXRCX5ZG7 EXPORT_FEATURES: NDVI_2014_281000 (COMPLETED)>
# <Task 2JFVIKD4TMFCFYS3J7LGS5I6 EXPORT_FEATURES: NDVI_2023_280000 (COMPLETED)>
# <Task BVRJ3GEFG2OUVAGDFPB3PT6U EXPORT_FEATURES: NDVI_2022_280000 (COMPLETED)>
# <Task 54KDBZ2DGD5QC2QFBZ3DMGFS EXPORT_FEATURES: NDVI_2021_280000 (COMPLETED)>
# <Task CFPV2CEIHDLDYPJI2JUY4WAU EXPORT_FEATURES: NDVI_2020_280000 (COMPLETED)>
# <Task DCPNLKNDTW7RNDBCAEID4EEJ EXPORT_FEATURES: NDVI_2019_280000 (COMPLETED)>
# <Task MP4KRCRKPXLICJK6N5XYDTJU EXPORT_FEATURES: NDVI_2018_280000 (COMPLETED)>
# <Task Q2WC75GW3NJK2EG6Q5MRADB7 EXPORT_FEATURES: NDVI_2017_280000 (COMPLETED)>
# <Task VLBRM7W4REG37L2DQ7LX7WY3 EXPORT_FEATURES: NDVI_2016_280000 (COMPLETED)>
# <Task JAW35EDWS2IENM2YB7RVOLSO EXPORT_FEATURES: NDVI_2015_280000 (COMPLETED)>
# <Task PDRD5A7RK6TSKN4LU7TIBGRX EXPORT_FEATURES: NDVI_2014_280000 (COMPLETED)>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 6
#       4 # Iterate through the tasks and cancel them
#       5 for task in tasks:
# ----> 6     task_status = task.status()
#       7     print(task)
#       8     if task_status['state'] in ['RUNNING', 'READY']:
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\ee\batch.py:176, in Task.status(self)
#     163 """Fetches the current status of the task.
#     164
#     165 Returns:
#    (...)
#     173   May also include other fields.
#     174 """
#     175 if self.operation_name:
# --> 176   operation = data.getOperation(self.operation_name)
#     177   result = _cloud_api_utils.convert_operation_to_task(operation)
#     178   if result['state'] == 'UNKNOWN':
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\ee\data.py:1724, in getOperation(operation_name)
#    1714 def getOperation(operation_name: str) -> Any:
#    1715   """Retrieves the status of a long-running operation.
#    1716
#    1717   Args:
#    (...)
#    1722     An Operation status dictionary for the requested operation.
#    1723   """
# -> 1724   return _execute_cloud_call(
#    1725       _get_cloud_projects().operations().get(name=operation_name)
#    1726   )
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\ee\data.py:406, in _execute_cloud_call(call, num_retries)
#     404 num_retries = _max_retries if num_retries is None else num_retries
#     405 try:
# --> 406   return call.execute(num_retries=num_retries)
#     407 except googleapiclient.errors.HttpError as e:
#     408   raise _translate_cloud_exception(e)
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\googleapiclient\http.py:923, in HttpRequest.execute(self, http, num_retries)
#     920     self.headers["content-length"] = str(len(self.body))
#     922 # Handle retries for server-side errors.
# --> 923 resp, content = _retry_request(
#     924     http,
#     925     num_retries,
#     926     "request",
#     927     self._sleep,
#     928     self._rand,
#     929     str(self.uri),
#     930     method=str(self.method),
#     931     body=self.body,
#     932     headers=self.headers,
#     933 )
#     935 for callback in self.response_callbacks:
#     936     callback(resp)
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\googleapiclient\http.py:191, in _retry_request(http, num_retries, req_type, sleep, rand, uri, method, *args, **kwargs)
#     189 try:
#     190     exception = None
# --> 191     resp, content = http.request(uri, method, *args, **kwargs)
#     192 # Retry on SSL errors and socket timeout errors.
#     193 except _ssl_SSLError as ssl_error:
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\google_auth_httplib2.py:218, in AuthorizedHttp.request(self, uri, method, body, headers, redirections, connection_type, **kwargs)
#     215     body_stream_position = body.tell()
#     217 # Make the request.
# --> 218 response, content = self.http.request(
#     219     uri,
#     220     method,
#     221     body=body,
#     222     headers=request_headers,
#     223     redirections=redirections,
#     224     connection_type=connection_type,
#     225     **kwargs
#     226 )
#     228 # If the response indicated that the credentials needed to be
#     229 # refreshed, then refresh the credentials and re-attempt the
#     230 # request.
#     231 # A stored token may expire between the time it is retrieved and
#     232 # the time the request is made, so we may need to try twice.
#     233 if (
#     234     response.status in self._refresh_status_codes
#     235     and _credential_refresh_attempt < self._max_refresh_attempts
#     236 ):
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\ee\_cloud_api_utils.py:70, in _Http.request(***failed resolving arguments***)
#      63 del redirections  # Ignored
#      65 try:
#      66   # googleapiclient is expecting an httplib2 object, and doesn't include
#      67   # requests error in the list of transient errors. Therefore, transient
#      68   # requests errors should be converted to kinds that googleapiclient
#      69   # consider transient.
# ---> 70   response = self._session.request(
#      71       method, uri, data=body, headers=headers, timeout=self._timeout
#      72   )
#      73 except requests.exceptions.ConnectionError as connection_error:
#      74   raise ConnectionError(connection_error) from connection_error
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\envs\geoenv\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\envs\geoenv\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\envs\geoenv\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\envs\geoenv\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\envs\geoenv\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File ~\anaconda3\envs\geoenv\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\envs\geoenv\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:
